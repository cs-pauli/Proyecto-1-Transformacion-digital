# %%
import re
import os
import xml.etree.ElementTree as ET

tree = ET.parse('/Users/paulacolladosaura/Desktop/adalab/Modulo 1/proyectos/project-DA-promo-b-modulo-1-team-3/BBDD/data_xml.xml')
root = tree.getroot()


xml_list = []
for child in root:
    xml_dict = {}
    for subchild in child:
        xml_dict[subchild.tag] = subchild.text
    xml_list.append(xml_dict) # Es una lista que contiene diccionarios

# %%
xml_list
# Out:
# [{'level_0': '1', 'index': '1', 'time': '784', 'age': '50-54', 'gender': '0'},
#  {'level_0': '2', 'index': '2', 'time': '924', 'age': '22-24', 'gender': '0'},
#  {'level_0': '3', 'index': '3', 'time': '575', 'age': '45-49', 'gender': '0'},
#  {'level_0': '4', 'index': '4', 'time': '781', 'age': '45-49', 'gender': '0'},
#  {'level_0': '5', 'index': '5', 'time': '1020', 'age': '25-29', 'gender': '1'},
#  {'level_0': '6', 'index': '6', 'time': '141', 'age': '18-21', 'gender': '1'},
#  {'level_0': '7', 'index': '7', 'time': '484', 'age': '30-34', 'gender': '0'},
#  {'level_0': '8', 'index': '8', 'time': '1744', 'age': '22-24', 'gender': '0'},
#  {'level_0': '9', 'index': '9', 'time': '655', 'age': '30-34', 'gender': '0'},
#  {'level_0': '10',
#   'index': '10',
#   'time': '1777',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '11',
#   'index': '11',
#   'time': '3081',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '12',
#   'index': '12',
#   'time': '1922',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '13',
#   'index': '13',
#   'time': '852',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '14',
#   'index': '14',
#   'time': '838',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '15',
#   'index': '15',
#   'time': '563',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '16',
#   'index': '16',
#   'time': '1315',
#   'age': '50-54',
#   'gender': '0'},
#  {'level_0': '17',
#   'index': '17',
#   'time': '479',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '18',
#   'index': '18',
#   'time': '249',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '19',
#   'index': '19',
#   'time': '650',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '20', 'index': '20', 'time': '1461', 'age': '70+', 'gender': '0'},
#  {'level_0': '21',
#   'index': '21',
#   'time': '551',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '22',
#   'index': '22',
#   'time': '258',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '23',
#   'index': '23',
#   'time': '773',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '24',
#   'index': '24',
#   'time': '630',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '25',
#   'index': '25',
#   'time': '2467',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '26',
#   'index': '26',
#   'time': '7750',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '27',
#   'index': '27',
#   'time': '607',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '28',
#   'index': '28',
#   'time': '525',
#   'age': '22-24',
#   'gender': '1'},
#  {'level_0': '29',
#   'index': '29',
#   'time': '501',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '30',
#   'index': '30',
#   'time': '415',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '31',
#   'index': '31',
#   'time': '317',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '32',
#   'index': '32',
#   'time': '171',
#   'age': '22-24',
#   'gender': '2'},
#  {'level_0': '33',
#   'index': '33',
#   'time': '744',
#   'age': '30-34',
#   'gender': '1'},
#  {'level_0': '34',
#   'index': '34',
#   'time': '668',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '35',
#   'index': '35',
#   'time': '460',
#   'age': '30-34',
#   'gender': '1'},
#  {'level_0': '36',
#   'index': '36',
#   'time': '244',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '37',
#   'index': '37',
#   'time': '901',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '38',
#   'index': '38',
#   'time': '625',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '39',
#   'index': '39',
#   'time': '1239',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '40',
#   'index': '40',
#   'time': '229993',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '41',
#   'index': '41',
#   'time': '312',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '42',
#   'index': '42',
#   'time': '976',
#   'age': '55-59',
#   'gender': '0'},
#  {'level_0': '43',
#   'index': '43',
#   'time': '1890',
#   'age': '30-34',
#   'gender': '1'},
#  {'level_0': '44',
#   'index': '44',
#   'time': '357',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '45',
#   'index': '45',
#   'time': '660',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '46',
#   'index': '46',
#   'time': '1524',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '47',
#   'index': '47',
#   'time': '453',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '48',
#   'index': '48',
#   'time': '793',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '49',
#   'index': '49',
#   'time': '557',
#   'age': '30-34',
#   'gender': '1'},
#  {'level_0': '50',
#   'index': '50',
#   'time': '5215',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '51',
#   'index': '51',
#   'time': '483',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '52',
#   'index': '52',
#   'time': '866',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '53',
#   'index': '53',
#   'time': '1045',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '54',
#   'index': '54',
#   'time': '359',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '55',
#   'index': '55',
#   'time': '1006',
#   'age': '22-24',
#   'gender': '1'},
#  {'level_0': '56',
#   'index': '56',
#   'time': '95756',
#   'age': '30-34',
#   'gender': '1'},
#  {'level_0': '57',
#   'index': '57',
#   'time': '642',
#   'age': '35-39',
#   'gender': '1'},
#  {'level_0': '58',
#   'index': '58',
#   'time': '528',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '59',
#   'index': '59',
#   'time': '1093',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '60',
#   'index': '60',
#   'time': '565',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '61',
#   'index': '61',
#   'time': '405',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '62',
#   'index': '62',
#   'time': '872',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '63',
#   'index': '63',
#   'time': '434',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '64',
#   'index': '64',
#   'time': '419',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '65',
#   'index': '65',
#   'time': '1479',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '66',
#   'index': '66',
#   'time': '665',
#   'age': '30-34',
#   'gender': '3'},
#  {'level_0': '67',
#   'index': '67',
#   'time': '1073',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '68',
#   'index': '68',
#   'time': '626',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '69',
#   'index': '69',
#   'time': '743',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '70',
#   'index': '70',
#   'time': '854',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '71',
#   'index': '71',
#   'time': '767',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '72',
#   'index': '72',
#   'time': '4971',
#   'age': '30-34',
#   'gender': '1'},
#  {'level_0': '73',
#   'index': '73',
#   'time': '560',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '74',
#   'index': '74',
#   'time': '2399',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '75',
#   'index': '75',
#   'time': '786',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '76',
#   'index': '76',
#   'time': '1293',
#   'age': '50-54',
#   'gender': '0'},
#  {'level_0': '77',
#   'index': '77',
#   'time': '395',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '78',
#   'index': '78',
#   'time': '555',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '79',
#   'index': '79',
#   'time': '77678',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '80',
#   'index': '80',
#   'time': '1643',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '81',
#   'index': '81',
#   'time': '3454',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '82',
#   'index': '82',
#   'time': '986',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '83',
#   'index': '83',
#   'time': '1062',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '84',
#   'index': '84',
#   'time': '161',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '85',
#   'index': '85',
#   'time': '648',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '86',
#   'index': '86',
#   'time': '432',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '87',
#   'index': '87',
#   'time': '508',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '88',
#   'index': '88',
#   'time': '463',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '89',
#   'index': '89',
#   'time': '642',
#   'age': '55-59',
#   'gender': '0'},
#  {'level_0': '90',
#   'index': '90',
#   'time': '50748',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '91',
#   'index': '91',
#   'time': '674',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '92',
#   'index': '92',
#   'time': '548',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '93',
#   'index': '93',
#   'time': '750',
#   'age': '55-59',
#   'gender': '0'},
#  {'level_0': '94',
#   'index': '94',
#   'time': '532',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '95',
#   'index': '95',
#   'time': '1423',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '96',
#   'index': '96',
#   'time': '661',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '97',
#   'index': '97',
#   'time': '638',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '98',
#   'index': '98',
#   'time': '585',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '99',
#   'index': '99',
#   'time': '370',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '100',
#   'index': '100',
#   'time': '174',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '101',
#   'index': '101',
#   'time': '294',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '102',
#   'index': '102',
#   'time': '681',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '103',
#   'index': '103',
#   'time': '444',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '104',
#   'index': '104',
#   'time': '543',
#   'age': '40-44',
#   'gender': '1'},
#  {'level_0': '105',
#   'index': '105',
#   'time': '824',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '106',
#   'index': '106',
#   'time': '3455',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '107',
#   'index': '107',
#   'time': '728',
#   'age': '55-59',
#   'gender': '0'},
#  {'level_0': '108',
#   'index': '108',
#   'time': '3097',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '109',
#   'index': '109',
#   'time': '531',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '110',
#   'index': '110',
#   'time': '699',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '111',
#   'index': '111',
#   'time': '378',
#   'age': '22-24',
#   'gender': '1'},
#  {'level_0': '112',
#   'index': '112',
#   'time': '2932',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '113',
#   'index': '113',
#   'time': '584',
#   'age': '30-34',
#   'gender': '1'},
#  {'level_0': '114',
#   'index': '114',
#   'time': '205',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '115',
#   'index': '115',
#   'time': '1050',
#   'age': '60-69',
#   'gender': '0'},
#  {'level_0': '116',
#   'index': '116',
#   'time': '61432',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '117',
#   'index': '117',
#   'time': '445',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '118',
#   'index': '118',
#   'time': '918',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '119',
#   'index': '119',
#   'time': '798',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '120',
#   'index': '120',
#   'time': '131',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '121',
#   'index': '121',
#   'time': '735',
#   'age': '70+',
#   'gender': '0'},
#  {'level_0': '122',
#   'index': '122',
#   'time': '654',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '123',
#   'index': '123',
#   'time': '2770',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '124',
#   'index': '124',
#   'time': '1533',
#   'age': '60-69',
#   'gender': '0'},
#  {'level_0': '125',
#   'index': '125',
#   'time': '2885',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '126',
#   'index': '126',
#   'time': '1730',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '127',
#   'index': '127',
#   'time': '379',
#   'age': '40-44',
#   'gender': '1'},
#  {'level_0': '128',
#   'index': '128',
#   'time': '763',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '129',
#   'index': '129',
#   'time': '694',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '130',
#   'index': '130',
#   'time': '776',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '131',
#   'index': '131',
#   'time': '737',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '132',
#   'index': '132',
#   'time': '514',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '133',
#   'index': '133',
#   'time': '647',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '134',
#   'index': '134',
#   'time': '386',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '135',
#   'index': '135',
#   'time': '2048',
#   'age': '30-34',
#   'gender': '1'},
#  {'level_0': '136',
#   'index': '136',
#   'time': '43508',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '137',
#   'index': '137',
#   'time': '401',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '138',
#   'index': '138',
#   'time': '682',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '139',
#   'index': '139',
#   'time': '753',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '140',
#   'index': '140',
#   'time': '352',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '141',
#   'index': '141',
#   'time': '566',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '142',
#   'index': '142',
#   'time': '1813',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '143',
#   'index': '143',
#   'time': '435',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '144',
#   'index': '144',
#   'time': '986',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '145',
#   'index': '145',
#   'time': '366',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '146',
#   'index': '146',
#   'time': '776',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '147',
#   'index': '147',
#   'time': '340',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '148',
#   'index': '148',
#   'time': '339',
#   'age': '30-34',
#   'gender': '1'},
#  {'level_0': '149',
#   'index': '149',
#   'time': '436',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '150',
#   'index': '150',
#   'time': '744',
#   'age': '70+',
#   'gender': '1'},
#  {'level_0': '151',
#   'index': '151',
#   'time': '895',
#   'age': '22-24',
#   'gender': '1'},
#  {'level_0': '152',
#   'index': '152',
#   'time': '79172',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '153',
#   'index': '153',
#   'time': '502',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '154',
#   'index': '154',
#   'time': '267',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '155',
#   'index': '155',
#   'time': '516',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '156',
#   'index': '156',
#   'time': '427',
#   'age': '22-24',
#   'gender': '1'},
#  {'level_0': '157',
#   'index': '157',
#   'time': '985',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '158',
#   'index': '158',
#   'time': '610',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '159',
#   'index': '159',
#   'time': '304',
#   'age': '22-24',
#   'gender': '1'},
#  {'level_0': '160',
#   'index': '160',
#   'time': '12878',
#   'age': '50-54',
#   'gender': '0'},
#  {'level_0': '161',
#   'index': '161',
#   'time': '526',
#   'age': '60-69',
#   'gender': '0'},
#  {'level_0': '162',
#   'index': '162',
#   'time': '1068',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '163',
#   'index': '163',
#   'time': '404',
#   'age': '22-24',
#   'gender': '1'},
#  {'level_0': '164',
#   'index': '164',
#   'time': '280',
#   'age': '50-54',
#   'gender': '0'},
#  {'level_0': '165',
#   'index': '165',
#   'time': '904',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '166',
#   'index': '166',
#   'time': '1565',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '167',
#   'index': '167',
#   'time': '3089',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '168',
#   'index': '168',
#   'time': '447',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '169',
#   'index': '169',
#   'time': '460',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '170',
#   'index': '170',
#   'time': '1846',
#   'age': '60-69',
#   'gender': '0'},
#  {'level_0': '171',
#   'index': '171',
#   'time': '980',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '172',
#   'index': '172',
#   'time': '660',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '173',
#   'index': '173',
#   'time': '937',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '174',
#   'index': '174',
#   'time': '476',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '175',
#   'index': '175',
#   'time': '553',
#   'age': '40-44',
#   'gender': '1'},
#  {'level_0': '176',
#   'index': '176',
#   'time': '412',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '177',
#   'index': '177',
#   'time': '324',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '178',
#   'index': '178',
#   'time': '1894',
#   'age': '22-24',
#   'gender': '1'},
#  {'level_0': '179',
#   'index': '179',
#   'time': '1762',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '180',
#   'index': '180',
#   'time': '866',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '181',
#   'index': '181',
#   'time': '24380',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '182',
#   'index': '182',
#   'time': '738',
#   'age': '22-24',
#   'gender': '1'},
#  {'level_0': '183',
#   'index': '183',
#   'time': '2032',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '184',
#   'index': '184',
#   'time': '2084',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '185',
#   'index': '185',
#   'time': '698',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '186',
#   'index': '186',
#   'time': '574',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '187',
#   'index': '187',
#   'time': '778',
#   'age': '60-69',
#   'gender': '0'},
#  {'level_0': '188',
#   'index': '188',
#   'time': '493',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '189',
#   'index': '189',
#   'time': '337',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '190',
#   'index': '190',
#   'time': '406',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '191',
#   'index': '191',
#   'time': '1677',
#   'age': '55-59',
#   'gender': '0'},
#  {'level_0': '192',
#   'index': '192',
#   'time': '348',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '193',
#   'index': '193',
#   'time': '536',
#   'age': '30-34',
#   'gender': '1'},
#  {'level_0': '194',
#   'index': '194',
#   'time': '186',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '195',
#   'index': '195',
#   'time': '354',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '196',
#   'index': '196',
#   'time': '375',
#   'age': '22-24',
#   'gender': '1'},
#  {'level_0': '197',
#   'index': '197',
#   'time': '677',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '198',
#   'index': '198',
#   'time': '456',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '199',
#   'index': '199',
#   'time': '916',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '200',
#   'index': '200',
#   'time': '571',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '201',
#   'index': '201',
#   'time': '720',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '202',
#   'index': '202',
#   'time': '539',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '203',
#   'index': '203',
#   'time': '1346',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '204',
#   'index': '204',
#   'time': '338',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '205',
#   'index': '205',
#   'time': '307',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '206',
#   'index': '206',
#   'time': '288',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '207',
#   'index': '207',
#   'time': '501',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '208',
#   'index': '208',
#   'time': '2331',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '209',
#   'index': '209',
#   'time': '3237',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '210',
#   'index': '210',
#   'time': '531',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '211',
#   'index': '211',
#   'time': '586',
#   'age': '30-34',
#   'gender': '2'},
#  {'level_0': '212',
#   'index': '212',
#   'time': '12370',
#   'age': '55-59',
#   'gender': '0'},
#  {'level_0': '213',
#   'index': '213',
#   'time': '1233',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '214',
#   'index': '214',
#   'time': '697',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '215',
#   'index': '215',
#   'time': '578',
#   'age': '35-39',
#   'gender': '1'},
#  {'level_0': '216',
#   'index': '216',
#   'time': '572',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '217',
#   'index': '217',
#   'time': '224',
#   'age': '18-21',
#   'gender': '3'},
#  {'level_0': '218',
#   'index': '218',
#   'time': '646',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '219',
#   'index': '219',
#   'time': '794',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '220',
#   'index': '220',
#   'time': '815',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '221',
#   'index': '221',
#   'time': '591',
#   'age': '60-69',
#   'gender': '0'},
#  {'level_0': '222',
#   'index': '222',
#   'time': '699',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '223',
#   'index': '223',
#   'time': '1124',
#   'age': '70+',
#   'gender': '0'},
#  {'level_0': '224',
#   'index': '224',
#   'time': '520',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '225',
#   'index': '225',
#   'time': '504',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '226',
#   'index': '226',
#   'time': '669',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '227',
#   'index': '227',
#   'time': '3042',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '228',
#   'index': '228',
#   'time': '982',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '229',
#   'index': '229',
#   'time': '613',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '230',
#   'index': '230',
#   'time': '798',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '231',
#   'index': '231',
#   'time': '875',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '232',
#   'index': '232',
#   'time': '307',
#   'age': '55-59',
#   'gender': '1'},
#  {'level_0': '233',
#   'index': '233',
#   'time': '4131',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '234',
#   'index': '234',
#   'time': '601',
#   'age': '50-54',
#   'gender': '0'},
#  {'level_0': '235',
#   'index': '235',
#   'time': '1341',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '236',
#   'index': '236',
#   'time': '612',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '237',
#   'index': '237',
#   'time': '275',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '238',
#   'index': '238',
#   'time': '1128',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '239',
#   'index': '239',
#   'time': '961',
#   'age': '50-54',
#   'gender': '0'},
#  {'level_0': '240',
#   'index': '240',
#   'time': '290',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '241',
#   'index': '241',
#   'time': '627',
#   'age': '30-34',
#   'gender': '1'},
#  {'level_0': '242',
#   'index': '242',
#   'time': '1348',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '243',
#   'index': '243',
#   'time': '780',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '244',
#   'index': '244',
#   'time': '9291',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '245',
#   'index': '245',
#   'time': '3874',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '246',
#   'index': '246',
#   'time': '1921',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '247',
#   'index': '247',
#   'time': '497',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '248',
#   'index': '248',
#   'time': '1181',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '249',
#   'index': '249',
#   'time': '688',
#   'age': '35-39',
#   'gender': '1'},
#  {'level_0': '250',
#   'index': '250',
#   'time': '449',
#   'age': '30-34',
#   'gender': '1'},
#  {'level_0': '251',
#   'index': '251',
#   'time': '320',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '252',
#   'index': '252',
#   'time': '767',
#   'age': '35-39',
#   'gender': '1'},
#  {'level_0': '253',
#   'index': '253',
#   'time': '667',
#   'age': '55-59',
#   'gender': '1'},
#  {'level_0': '254',
#   'index': '254',
#   'time': '170',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '255',
#   'index': '255',
#   'time': '991',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '256',
#   'index': '256',
#   'time': '1846',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '257',
#   'index': '257',
#   'time': '732',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '258',
#   'index': '258',
#   'time': '566',
#   'age': '60-69',
#   'gender': '0'},
#  {'level_0': '259',
#   'index': '259',
#   'time': '1075',
#   'age': '50-54',
#   'gender': '0'},
#  {'level_0': '260',
#   'index': '260',
#   'time': '442',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '261',
#   'index': '261',
#   'time': '1469',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '262',
#   'index': '262',
#   'time': '526',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '263',
#   'index': '263',
#   'time': '824',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '264',
#   'index': '264',
#   'time': '922',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '265',
#   'index': '265',
#   'time': '378',
#   'age': '35-39',
#   'gender': '1'},
#  {'level_0': '266',
#   'index': '266',
#   'time': '1945',
#   'age': '45-49',
#   'gender': '3'},
#  {'level_0': '267',
#   'index': '267',
#   'time': '578',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '268',
#   'index': '268',
#   'time': '237',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '269',
#   'index': '269',
#   'time': '756',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '270',
#   'index': '270',
#   'time': '599',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '271',
#   'index': '271',
#   'time': '480',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '272',
#   'index': '272',
#   'time': '264',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '273',
#   'index': '273',
#   'time': '4088',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '274',
#   'index': '274',
#   'time': '1066',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '275',
#   'index': '275',
#   'time': '509',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '276',
#   'index': '276',
#   'time': '187',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '277',
#   'index': '277',
#   'time': '372',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '278',
#   'index': '278',
#   'time': '356',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '279',
#   'index': '279',
#   'time': '445',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '280',
#   'index': '280',
#   'time': '841',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '281',
#   'index': '281',
#   'time': '569',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '282',
#   'index': '282',
#   'time': '984',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '283',
#   'index': '283',
#   'time': '85290',
#   'age': '50-54',
#   'gender': '0'},
#  {'level_0': '284',
#   'index': '284',
#   'time': '3143',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '285',
#   'index': '285',
#   'time': '1159',
#   'age': '45-49',
#   'gender': '1'},
#  {'level_0': '286',
#   'index': '286',
#   'time': '5097',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '287',
#   'index': '287',
#   'time': '501',
#   'age': '35-39',
#   'gender': '1'},
#  {'level_0': '288',
#   'index': '288',
#   'time': '622',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '289',
#   'index': '289',
#   'time': '785',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '290',
#   'index': '290',
#   'time': '489',
#   'age': '22-24',
#   'gender': '1'},
#  {'level_0': '291',
#   'index': '291',
#   'time': '1984',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '292',
#   'index': '292',
#   'time': '1112',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '293',
#   'index': '293',
#   'time': '904',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '294',
#   'index': '294',
#   'time': '2403',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '295',
#   'index': '295',
#   'time': '29434',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '296',
#   'index': '296',
#   'time': '489',
#   'age': '30-34',
#   'gender': '1'},
#  {'level_0': '297',
#   'index': '297',
#   'time': '843',
#   'age': '50-54',
#   'gender': '0'},
#  {'level_0': '298',
#   'index': '298',
#   'time': '42500',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '299',
#   'index': '299',
#   'time': '266',
#   'age': '50-54',
#   'gender': '0'},
#  {'level_0': '300',
#   'index': '300',
#   'time': '1390',
#   'age': '30-34',
#   'gender': '1'},
#  {'level_0': '301',
#   'index': '301',
#   'time': '887',
#   'age': '25-29',
#   'gender': '3'},
#  {'level_0': '302',
#   'index': '302',
#   'time': '662',
#   'age': '22-24',
#   'gender': '1'},
#  {'level_0': '303',
#   'index': '303',
#   'time': '559',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '304',
#   'index': '304',
#   'time': '774',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '305',
#   'index': '305',
#   'time': '603',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '306',
#   'index': '306',
#   'time': '550',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '307',
#   'index': '307',
#   'time': '3074',
#   'age': '30-34',
#   'gender': '2'},
#  {'level_0': '308',
#   'index': '308',
#   'time': '161',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '309',
#   'index': '309',
#   'time': '828',
#   'age': '35-39',
#   'gender': '1'},
#  {'level_0': '310',
#   'index': '310',
#   'time': '994',
#   'age': '60-69',
#   'gender': '0'},
#  {'level_0': '311',
#   'index': '311',
#   'time': '545',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '312',
#   'index': '312',
#   'time': '544',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '313',
#   'index': '313',
#   'time': '358',
#   'age': '60-69',
#   'gender': '0'},
#  {'level_0': '314',
#   'index': '314',
#   'time': '364',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '315',
#   'index': '315',
#   'time': '771',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '316',
#   'index': '316',
#   'time': '345',
#   'age': '35-39',
#   'gender': '1'},
#  {'level_0': '317',
#   'index': '317',
#   'time': '231',
#   'age': '22-24',
#   'gender': '1'},
#  {'level_0': '318',
#   'index': '318',
#   'time': '255',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '319',
#   'index': '319',
#   'time': '6005',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '320',
#   'index': '320',
#   'time': '245',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '321',
#   'index': '321',
#   'time': '166328',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '322',
#   'index': '322',
#   'time': '1072',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '323',
#   'index': '323',
#   'time': '1272',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '324',
#   'index': '324',
#   'time': '434',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '325',
#   'index': '325',
#   'time': '4573',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '326',
#   'index': '326',
#   'time': '584',
#   'age': '30-34',
#   'gender': '1'},
#  {'level_0': '327',
#   'index': '327',
#   'time': '979',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '328',
#   'index': '328',
#   'time': '166',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '329',
#   'index': '329',
#   'time': '673',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '330',
#   'index': '330',
#   'time': '230',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '331',
#   'index': '331',
#   'time': '39789',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '332',
#   'index': '332',
#   'time': '3588',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '333',
#   'index': '333',
#   'time': '784',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '334',
#   'index': '334',
#   'time': '642',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '335',
#   'index': '335',
#   'time': '1028',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '336',
#   'index': '336',
#   'time': '1508',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '337',
#   'index': '337',
#   'time': '151',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '338',
#   'index': '338',
#   'time': '867',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '339',
#   'index': '339',
#   'time': '451',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '340',
#   'index': '340',
#   'time': '429',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '341',
#   'index': '341',
#   'time': '1135',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '342',
#   'index': '342',
#   'time': '799',
#   'age': '70+',
#   'gender': '0'},
#  {'level_0': '343',
#   'index': '343',
#   'time': '454',
#   'age': '50-54',
#   'gender': '0'},
#  {'level_0': '344',
#   'index': '344',
#   'time': '424',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '345',
#   'index': '345',
#   'time': '1089',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '346',
#   'index': '346',
#   'time': '749',
#   'age': '55-59',
#   'gender': '0'},
#  {'level_0': '347',
#   'index': '347',
#   'time': '496',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '348',
#   'index': '348',
#   'time': '505',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '349',
#   'index': '349',
#   'time': '5394',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '350',
#   'index': '350',
#   'time': '319',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '351',
#   'index': '351',
#   'time': '639',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '352',
#   'index': '352',
#   'time': '405',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '353',
#   'index': '353',
#   'time': '808',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '354',
#   'index': '354',
#   'time': '1011',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '355',
#   'index': '355',
#   'time': '780',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '356',
#   'index': '356',
#   'time': '642',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '357',
#   'index': '357',
#   'time': '623',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '358',
#   'index': '358',
#   'time': '450',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '359',
#   'index': '359',
#   'time': '951',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '360',
#   'index': '360',
#   'time': '244',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '361',
#   'index': '361',
#   'time': '365',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '362',
#   'index': '362',
#   'time': '589',
#   'age': '55-59',
#   'gender': '0'},
#  {'level_0': '363',
#   'index': '363',
#   'time': '502',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '364',
#   'index': '364',
#   'time': '1276',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '365',
#   'index': '365',
#   'time': '2017',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '366',
#   'index': '366',
#   'time': '700561',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '367',
#   'index': '367',
#   'time': '415',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '368',
#   'index': '368',
#   'time': '2355',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '369',
#   'index': '369',
#   'time': '699',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '370',
#   'index': '370',
#   'time': '1724',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '371',
#   'index': '371',
#   'time': '454',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '372',
#   'index': '372',
#   'time': '997',
#   'age': '50-54',
#   'gender': '0'},
#  {'level_0': '373',
#   'index': '373',
#   'time': '3411',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '374',
#   'index': '374',
#   'time': '569',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '375',
#   'index': '375',
#   'time': '1254',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '376',
#   'index': '376',
#   'time': '1507',
#   'age': '60-69',
#   'gender': '0'},
#  {'level_0': '377',
#   'index': '377',
#   'time': '569',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '378',
#   'index': '378',
#   'time': '1020',
#   'age': '60-69',
#   'gender': '0'},
#  {'level_0': '379',
#   'index': '379',
#   'time': '945',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '380',
#   'index': '380',
#   'time': '1028',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '381',
#   'index': '381',
#   'time': '585',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '382',
#   'index': '382',
#   'time': '1489',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '383',
#   'index': '383',
#   'time': '392',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '384',
#   'index': '384',
#   'time': '3301',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '385',
#   'index': '385',
#   'time': '257',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '386',
#   'index': '386',
#   'time': '973',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '387',
#   'index': '387',
#   'time': '458',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '388',
#   'index': '388',
#   'time': '353',
#   'age': '18-21',
#   'gender': '3'},
#  {'level_0': '389',
#   'index': '389',
#   'time': '987',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '390',
#   'index': '390',
#   'time': '1208',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '391',
#   'index': '391',
#   'time': '482',
#   'age': '50-54',
#   'gender': '0'},
#  {'level_0': '392',
#   'index': '392',
#   'time': '788',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '393',
#   'index': '393',
#   'time': '521',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '394',
#   'index': '394',
#   'time': '1114',
#   'age': '50-54',
#   'gender': '1'},
#  {'level_0': '395',
#   'index': '395',
#   'time': '1133',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '396',
#   'index': '396',
#   'time': '856',
#   'age': '50-54',
#   'gender': '0'},
#  {'level_0': '397',
#   'index': '397',
#   'time': '974',
#   'age': '50-54',
#   'gender': '0'},
#  {'level_0': '398',
#   'index': '398',
#   'time': '358',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '399',
#   'index': '399',
#   'time': '602',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '400',
#   'index': '400',
#   'time': '610',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '401',
#   'index': '401',
#   'time': '1755',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '402',
#   'index': '402',
#   'time': '733',
#   'age': '22-24',
#   'gender': '1'},
#  {'level_0': '403',
#   'index': '403',
#   'time': '984',
#   'age': '35-39',
#   'gender': '1'},
#  {'level_0': '404',
#   'index': '404',
#   'time': '1155',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '405',
#   'index': '405',
#   'time': '4082',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '406',
#   'index': '406',
#   'time': '918',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '407',
#   'index': '407',
#   'time': '779',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '408',
#   'index': '408',
#   'time': '394',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '409',
#   'index': '409',
#   'time': '670',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '410',
#   'index': '410',
#   'time': '2239',
#   'age': '55-59',
#   'gender': '1'},
#  {'level_0': '411',
#   'index': '411',
#   'time': '2377',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '412',
#   'index': '412',
#   'time': '572',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '413',
#   'index': '413',
#   'time': '913',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '414',
#   'index': '414',
#   'time': '764',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '415',
#   'index': '415',
#   'time': '601',
#   'age': '45-49',
#   'gender': '1'},
#  {'level_0': '416',
#   'index': '416',
#   'time': '663',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '417',
#   'index': '417',
#   'time': '659',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '418',
#   'index': '418',
#   'time': '1497',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '419',
#   'index': '419',
#   'time': '3356',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '420',
#   'index': '420',
#   'time': '838',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '421',
#   'index': '421',
#   'time': '270',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '422',
#   'index': '422',
#   'time': '943',
#   'age': '40-44',
#   'gender': '3'},
#  {'level_0': '423',
#   'index': '423',
#   'time': '1877',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '424',
#   'index': '424',
#   'time': '914',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '425',
#   'index': '425',
#   'time': '1441',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '426',
#   'index': '426',
#   'time': '310',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '427',
#   'index': '427',
#   'time': '1003',
#   'age': '35-39',
#   'gender': '1'},
#  {'level_0': '428',
#   'index': '428',
#   'time': '481',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '429',
#   'index': '429',
#   'time': '639',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '430',
#   'index': '430',
#   'time': '616',
#   'age': '30-34',
#   'gender': '1'},
#  {'level_0': '431',
#   'index': '431',
#   'time': '704',
#   'age': '30-34',
#   'gender': '1'},
#  {'level_0': '432',
#   'index': '432',
#   'time': '899193',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '433',
#   'index': '433',
#   'time': '899',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '434',
#   'index': '434',
#   'time': '572',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '435',
#   'index': '435',
#   'time': '330',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '436',
#   'index': '436',
#   'time': '1080',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '437',
#   'index': '437',
#   'time': '8327',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '438',
#   'index': '438',
#   'time': '403',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '439',
#   'index': '439',
#   'time': '448',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '440',
#   'index': '440',
#   'time': '541',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '441',
#   'index': '441',
#   'time': '883',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '442',
#   'index': '442',
#   'time': '155',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '443',
#   'index': '443',
#   'time': '995',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '444',
#   'index': '444',
#   'time': '772',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '445',
#   'index': '445',
#   'time': '448',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '446',
#   'index': '446',
#   'time': '2046',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '447',
#   'index': '447',
#   'time': '642',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '448',
#   'index': '448',
#   'time': '703',
#   'age': '35-39',
#   'gender': '1'},
#  {'level_0': '449',
#   'index': '449',
#   'time': '994',
#   'age': '22-24',
#   'gender': '4'},
#  {'level_0': '450',
#   'index': '450',
#   'time': '316',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '451',
#   'index': '451',
#   'time': '1004',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '452',
#   'index': '452',
#   'time': '1556',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '453',
#   'index': '453',
#   'time': '447',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '454',
#   'index': '454',
#   'time': '387',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '455',
#   'index': '455',
#   'time': '1230',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '456',
#   'index': '456',
#   'time': '447',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '457',
#   'index': '457',
#   'time': '644',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '458',
#   'index': '458',
#   'time': '689',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '459',
#   'index': '459',
#   'time': '628',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '460',
#   'index': '460',
#   'time': '439',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '461',
#   'index': '461',
#   'time': '605',
#   'age': '30-34',
#   'gender': '1'},
#  {'level_0': '462',
#   'index': '462',
#   'time': '208',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '463',
#   'index': '463',
#   'time': '820',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '464',
#   'index': '464',
#   'time': '224',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '465',
#   'index': '465',
#   'time': '319',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '466',
#   'index': '466',
#   'time': '1549',
#   'age': '50-54',
#   'gender': '0'},
#  {'level_0': '467',
#   'index': '467',
#   'time': '658',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '468',
#   'index': '468',
#   'time': '395',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '469',
#   'index': '469',
#   'time': '1459',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '470',
#   'index': '470',
#   'time': '1374',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '471',
#   'index': '471',
#   'time': '11771',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '472',
#   'index': '472',
#   'time': '774',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '473',
#   'index': '473',
#   'time': '584',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '474',
#   'index': '474',
#   'time': '22868',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '475',
#   'index': '475',
#   'time': '323',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '476',
#   'index': '476',
#   'time': '414',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '477',
#   'index': '477',
#   'time': '1927',
#   'age': '22-24',
#   'gender': '1'},
#  {'level_0': '478',
#   'index': '478',
#   'time': '293',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '479',
#   'index': '479',
#   'time': '501',
#   'age': '22-24',
#   'gender': '1'},
#  {'level_0': '480',
#   'index': '480',
#   'time': '248332',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '481',
#   'index': '481',
#   'time': '948',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '482',
#   'index': '482',
#   'time': '964611',
#   'age': '50-54',
#   'gender': '1'},
#  {'level_0': '483',
#   'index': '483',
#   'time': '909',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '484',
#   'index': '484',
#   'time': '1259',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '485',
#   'index': '485',
#   'time': '387',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '486',
#   'index': '486',
#   'time': '834',
#   'age': '35-39',
#   'gender': '3'},
#  {'level_0': '487',
#   'index': '487',
#   'time': '781',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '488',
#   'index': '488',
#   'time': '1721',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '489',
#   'index': '489',
#   'time': '534',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '490',
#   'index': '490',
#   'time': '652',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '491',
#   'index': '491',
#   'time': '756',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '492',
#   'index': '492',
#   'time': '390',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '493',
#   'index': '493',
#   'time': '223',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '494',
#   'index': '494',
#   'time': '492',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '495',
#   'index': '495',
#   'time': '680',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '496',
#   'index': '496',
#   'time': '1405',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '497',
#   'index': '497',
#   'time': '1073',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '498',
#   'index': '498',
#   'time': '926',
#   'age': '55-59',
#   'gender': '0'},
#  {'level_0': '499',
#   'index': '499',
#   'time': '426',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '500',
#   'index': '500',
#   'time': '267',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '501',
#   'index': '501',
#   'time': '198',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '502',
#   'index': '502',
#   'time': '410',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '503',
#   'index': '503',
#   'time': '874',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '504',
#   'index': '504',
#   'time': '539',
#   'age': '30-34',
#   'gender': '1'},
#  {'level_0': '505',
#   'index': '505',
#   'time': '439',
#   'age': '60-69',
#   'gender': '0'},
#  {'level_0': '506',
#   'index': '506',
#   'time': '605',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '507',
#   'index': '507',
#   'time': '599',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '508',
#   'index': '508',
#   'time': '274',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '509',
#   'index': '509',
#   'time': '444',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '510',
#   'index': '510',
#   'time': '2696',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '511',
#   'index': '511',
#   'time': '1283',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '512',
#   'index': '512',
#   'time': '359',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '513',
#   'index': '513',
#   'time': '503',
#   'age': '35-39',
#   'gender': '1'},
#  {'level_0': '514',
#   'index': '514',
#   'time': '27716',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '515',
#   'index': '515',
#   'time': '679',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '516',
#   'index': '516',
#   'time': '803',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '517',
#   'index': '517',
#   'time': '850',
#   'age': '50-54',
#   'gender': '0'},
#  {'level_0': '518',
#   'index': '518',
#   'time': '553',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '519',
#   'index': '519',
#   'time': '373',
#   'age': '50-54',
#   'gender': '0'},
#  {'level_0': '520',
#   'index': '520',
#   'time': '86661',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '521',
#   'index': '521',
#   'time': '569',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '522',
#   'index': '522',
#   'time': '411',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '523',
#   'index': '523',
#   'time': '957',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '524',
#   'index': '524',
#   'time': '738',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '525',
#   'index': '525',
#   'time': '1008',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '526',
#   'index': '526',
#   'time': '399',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '527',
#   'index': '527',
#   'time': '537',
#   'age': '55-59',
#   'gender': '0'},
#  {'level_0': '528',
#   'index': '528',
#   'time': '152',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '529',
#   'index': '529',
#   'time': '667',
#   'age': '22-24',
# ...
#  {'level_0': '826',
#   'index': '826',
#   'time': '465',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '827',
#   'index': '827',
#   'time': '835',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '828',
#   'index': '828',
#   'time': '254',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '829',
#   'index': '829',
#   'time': '5543',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '830',
#   'index': '830',
#   'time': '617',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '831',
#   'index': '831',
#   'time': '96873',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '832',
#   'index': '832',
#   'time': '239',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '833',
#   'index': '833',
#   'time': '1671',
#   'age': '30-34',
#   'gender': '1'},
#  {'level_0': '834',
#   'index': '834',
#   'time': '834',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '835',
#   'index': '835',
#   'time': '497',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '836',
#   'index': '836',
#   'time': '379',
#   'age': '30-34',
#   'gender': '1'},
#  {'level_0': '837',
#   'index': '837',
#   'time': '634',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '838',
#   'index': '838',
#   'time': '4040',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '839',
#   'index': '839',
#   'time': '1305',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '840',
#   'index': '840',
#   'time': '761',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '841',
#   'index': '841',
#   'time': '811',
#   'age': '50-54',
#   'gender': '0'},
#  {'level_0': '842',
#   'index': '842',
#   'time': '716',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '843',
#   'index': '843',
#   'time': '404',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '844',
#   'index': '844',
#   'time': '225',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '845',
#   'index': '845',
#   'time': '796',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '846',
#   'index': '846',
#   'time': '984',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '847',
#   'index': '847',
#   'time': '624',
#   'age': '60-69',
#   'gender': '0'},
#  {'level_0': '848',
#   'index': '848',
#   'time': '687',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '849',
#   'index': '849',
#   'time': '1678',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '850',
#   'index': '850',
#   'time': '481',
#   'age': '35-39',
#   'gender': '1'},
#  {'level_0': '851',
#   'index': '851',
#   'time': '214',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '852',
#   'index': '852',
#   'time': '418',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '853',
#   'index': '853',
#   'time': '312',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '854',
#   'index': '854',
#   'time': '608',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '855',
#   'index': '855',
#   'time': '785',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '856',
#   'index': '856',
#   'time': '1423',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '857',
#   'index': '857',
#   'time': '504',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '858',
#   'index': '858',
#   'time': '1450',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '859',
#   'index': '859',
#   'time': '826',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '860',
#   'index': '860',
#   'time': '902',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '861',
#   'index': '861',
#   'time': '830',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '862',
#   'index': '862',
#   'time': '1070',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '863',
#   'index': '863',
#   'time': '308',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '864',
#   'index': '864',
#   'time': '174416',
#   'age': '50-54',
#   'gender': '0'},
#  {'level_0': '865',
#   'index': '865',
#   'time': '381',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '866',
#   'index': '866',
#   'time': '693',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '867',
#   'index': '867',
#   'time': '691',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '868',
#   'index': '868',
#   'time': '366',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '869',
#   'index': '869',
#   'time': '1000',
#   'age': '55-59',
#   'gender': '0'},
#  {'level_0': '870',
#   'index': '870',
#   'time': '481',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '871',
#   'index': '871',
#   'time': '520',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '872',
#   'index': '872',
#   'time': '691',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '873',
#   'index': '873',
#   'time': '752',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '874',
#   'index': '874',
#   'time': '307',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '875',
#   'index': '875',
#   'time': '506',
#   'age': '60-69',
#   'gender': '1'},
#  {'level_0': '876',
#   'index': '876',
#   'time': '138',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '877',
#   'index': '877',
#   'time': '590',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '878',
#   'index': '878',
#   'time': '449',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '879',
#   'index': '879',
#   'time': '1217',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '880',
#   'index': '880',
#   'time': '714',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '881',
#   'index': '881',
#   'time': '4584',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '882',
#   'index': '882',
#   'time': '581',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '883',
#   'index': '883',
#   'time': '360',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '884',
#   'index': '884',
#   'time': '49733',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '885',
#   'index': '885',
#   'time': '995',
#   'age': '30-34',
#   'gender': '1'},
#  {'level_0': '886',
#   'index': '886',
#   'time': '32872',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '887',
#   'index': '887',
#   'time': '344',
#   'age': '35-39',
#   'gender': '1'},
#  {'level_0': '888',
#   'index': '888',
#   'time': '1144',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '889',
#   'index': '889',
#   'time': '646',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '890',
#   'index': '890',
#   'time': '213',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '891',
#   'index': '891',
#   'time': '329',
#   'age': '40-44',
#   'gender': '1'},
#  {'level_0': '892',
#   'index': '892',
#   'time': '433',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '893',
#   'index': '893',
#   'time': '386',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '894',
#   'index': '894',
#   'time': '1142',
#   'age': '50-54',
#   'gender': '0'},
#  {'level_0': '895',
#   'index': '895',
#   'time': '474',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '896',
#   'index': '896',
#   'time': '1096',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '897',
#   'index': '897',
#   'time': '494',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '898',
#   'index': '898',
#   'time': '648',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '899',
#   'index': '899',
#   'time': '1831',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '900',
#   'index': '900',
#   'time': '1327',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '901',
#   'index': '901',
#   'time': '366',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '902',
#   'index': '902',
#   'time': '408',
#   'age': '60-69',
#   'gender': '0'},
#  {'level_0': '903',
#   'index': '903',
#   'time': '461',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '904',
#   'index': '904',
#   'time': '692',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '905',
#   'index': '905',
#   'time': '393',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '906',
#   'index': '906',
#   'time': '332',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '907',
#   'index': '907',
#   'time': '826',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '908',
#   'index': '908',
#   'time': '426',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '909',
#   'index': '909',
#   'time': '802',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '910',
#   'index': '910',
#   'time': '3434',
#   'age': '40-44',
#   'gender': '1'},
#  {'level_0': '911',
#   'index': '911',
#   'time': '388',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '912',
#   'index': '912',
#   'time': '577',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '913',
#   'index': '913',
#   'time': '483',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '914',
#   'index': '914',
#   'time': '761',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '915',
#   'index': '915',
#   'time': '3179',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '916',
#   'index': '916',
#   'time': '7688',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '917',
#   'index': '917',
#   'time': '775',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '918',
#   'index': '918',
#   'time': '594',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '919',
#   'index': '919',
#   'time': '862',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '920',
#   'index': '920',
#   'time': '607',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '921',
#   'index': '921',
#   'time': '557',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '922',
#   'index': '922',
#   'time': '10121',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '923',
#   'index': '923',
#   'time': '250',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '924',
#   'index': '924',
#   'time': '945',
#   'age': '55-59',
#   'gender': '0'},
#  {'level_0': '925',
#   'index': '925',
#   'time': '639',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '926',
#   'index': '926',
#   'time': '140',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '927',
#   'index': '927',
#   'time': '690',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '928',
#   'index': '928',
#   'time': '1255',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '929',
#   'index': '929',
#   'time': '810',
#   'age': '70+',
#   'gender': '0'},
#  {'level_0': '930',
#   'index': '930',
#   'time': '789',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '931',
#   'index': '931',
#   'time': '11688',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '932',
#   'index': '932',
#   'time': '636',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '933',
#   'index': '933',
#   'time': '1890',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '934',
#   'index': '934',
#   'time': '1304',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '935',
#   'index': '935',
#   'time': '878',
#   'age': '60-69',
#   'gender': '0'},
#  {'level_0': '936',
#   'index': '936',
#   'time': '360',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '937',
#   'index': '937',
#   'time': '737',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '938',
#   'index': '938',
#   'time': '19523',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '939',
#   'index': '939',
#   'time': '253',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '940',
#   'index': '940',
#   'time': '230',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '941',
#   'index': '941',
#   'time': '371',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '942',
#   'index': '942',
#   'time': '406',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '943',
#   'index': '943',
#   'time': '1769',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '944',
#   'index': '944',
#   'time': '2639',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '945',
#   'index': '945',
#   'time': '163',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '946',
#   'index': '946',
#   'time': '518',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '947',
#   'index': '947',
#   'time': '168',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '948',
#   'index': '948',
#   'time': '976',
#   'age': '55-59',
#   'gender': '0'},
#  {'level_0': '949',
#   'index': '949',
#   'time': '1047088',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '950',
#   'index': '950',
#   'time': '1203',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '951',
#   'index': '951',
#   'time': '725',
#   'age': '30-34',
#   'gender': '1'},
#  {'level_0': '952',
#   'index': '952',
#   'time': '2978',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '953',
#   'index': '953',
#   'time': '519',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '954',
#   'index': '954',
#   'time': '1709',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '955',
#   'index': '955',
#   'time': '544',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '956',
#   'index': '956',
#   'time': '357',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '957',
#   'index': '957',
#   'time': '477',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '958',
#   'index': '958',
#   'time': '705',
#   'age': '35-39',
#   'gender': '1'},
#  {'level_0': '959',
#   'index': '959',
#   'time': '627',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '960',
#   'index': '960',
#   'time': '123158',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '961',
#   'index': '961',
#   'time': '280',
#   'age': '50-54',
#   'gender': '1'},
#  {'level_0': '962',
#   'index': '962',
#   'time': '472',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '963',
#   'index': '963',
#   'time': '834',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '964',
#   'index': '964',
#   'time': '542',
#   'age': '22-24',
#   'gender': '1'},
#  {'level_0': '965',
#   'index': '965',
#   'time': '605',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '966',
#   'index': '966',
#   'time': '1592',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '967',
#   'index': '967',
#   'time': '548',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '968',
#   'index': '968',
#   'time': '653',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '969',
#   'index': '969',
#   'time': '715',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '970',
#   'index': '970',
#   'time': '706',
#   'age': '35-39',
#   'gender': '0'},
#  {'level_0': '971',
#   'index': '971',
#   'time': '658',
#   'age': '30-34',
#   'gender': '1'},
#  {'level_0': '972',
#   'index': '972',
#   'time': '296',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '973',
#   'index': '973',
#   'time': '911',
#   'age': '40-44',
#   'gender': '1'},
#  {'level_0': '974',
#   'index': '974',
#   'time': '680',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '975',
#   'index': '975',
#   'time': '602',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '976',
#   'index': '976',
#   'time': '684',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '977',
#   'index': '977',
#   'time': '1112',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '978',
#   'index': '978',
#   'time': '455',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '979',
#   'index': '979',
#   'time': '497',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '980',
#   'index': '980',
#   'time': '342',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '981',
#   'index': '981',
#   'time': '2308',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '982',
#   'index': '982',
#   'time': '677',
#   'age': '40-44',
#   'gender': '0'},
#  {'level_0': '983',
#   'index': '983',
#   'time': '935',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '984',
#   'index': '984',
#   'time': '371',
#   'age': '22-24',
#   'gender': '1'},
#  {'level_0': '985',
#   'index': '985',
#   'time': '524',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '986',
#   'index': '986',
#   'time': '271',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '987',
#   'index': '987',
#   'time': '861',
#   'age': '40-44',
#   'gender': '1'},
#  {'level_0': '988',
#   'index': '988',
#   'time': '341',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '989',
#   'index': '989',
#   'time': '575',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '990',
#   'index': '990',
#   'time': '946',
#   'age': '45-49',
#   'gender': '0'},
#  {'level_0': '991',
#   'index': '991',
#   'time': '3800',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '992',
#   'index': '992',
#   'time': '263',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '993',
#   'index': '993',
#   'time': '539',
#   'age': '18-21',
#   'gender': '1'},
#  {'level_0': '994',
#   'index': '994',
#   'time': '489',
#   'age': '30-34',
#   'gender': '0'},
#  {'level_0': '995',
#   'index': '995',
#   'time': '4121',
#   'age': '22-24',
#   'gender': '0'},
#  {'level_0': '996',
#   'index': '996',
#   'time': '226154',
#   'age': '25-29',
#   'gender': '0'},
#  {'level_0': '997',
#   'index': '997',
#   'time': '516',
#   'age': '35-39',
#   'gender': '1'},
#  {'level_0': '998',
#   'index': '998',
#   'time': '1415',
#   'age': '18-21',
#   'gender': '0'},
#  {'level_0': '999',
#   'index': '999',
#   'time': '167',
#   'age': '25-29',
#   'gender': '1'},
#  {'level_0': '1000',
#   'index': '1000',
#   'time': '309',
#   'age': '22-24',
#   'gender': '1'},
#  ...]

# %%
print(xml_list)
# Out:
# [{'level_0': '1', 'index': '1', 'time': '784', 'age': '50-54', 'gender': '0'}, {'level_0': '2', 'index': '2', 'time': '924', 'age': '22-24', 'gender': '0'}, {'level_0': '3', 'index': '3', 'time': '575', 'age': '45-49', 'gender': '0'}, {'level_0': '4', 'index': '4', 'time': '781', 'age': '45-49', 'gender': '0'}, {'level_0': '5', 'index': '5', 'time': '1020', 'age': '25-29', 'gender': '1'}, {'level_0': '6', 'index': '6', 'time': '141', 'age': '18-21', 'gender': '1'}, {'level_0': '7', 'index': '7', 'time': '484', 'age': '30-34', 'gender': '0'}, {'level_0': '8', 'index': '8', 'time': '1744', 'age': '22-24', 'gender': '0'}, {'level_0': '9', 'index': '9', 'time': '655', 'age': '30-34', 'gender': '0'}, {'level_0': '10', 'index': '10', 'time': '1777', 'age': '40-44', 'gender': '0'}, {'level_0': '11', 'index': '11', 'time': '3081', 'age': '18-21', 'gender': '1'}, {'level_0': '12', 'index': '12', 'time': '1922', 'age': '18-21', 'gender': '1'}, {'level_0': '13', 'index': '13', 'time': '852', 'age': '45-49', 'gender': '0'}, {'level_0': '14', 'index': '14', 'time': '838', 'age': '22-24', 'gender': '0'}, {'level_0': '15', 'index': '15', 'time': '563', 'age': '35-39', 'gender': '0'}, {'level_0': '16', 'index': '16', 'time': '1315', 'age': '50-54', 'gender': '0'}, {'level_0': '17', 'index': '17', 'time': '479', 'age': '18-21', 'gender': '0'}, {'level_0': '18', 'index': '18', 'time': '249', 'age': '22-24', 'gender': '0'}, {'level_0': '19', 'index': '19', 'time': '650', 'age': '30-34', 'gender': '0'}, {'level_0': '20', 'index': '20', 'time': '1461', 'age': '70+', 'gender': '0'}, {'level_0': '21', 'index': '21', 'time': '551', 'age': '25-29', 'gender': '1'}, {'level_0': '22', 'index': '22', 'time': '258', 'age': '30-34', 'gender': '0'}, {'level_0': '23', 'index': '23', 'time': '773', 'age': '35-39', 'gender': '0'}, {'level_0': '24', 'index': '24', 'time': '630', 'age': '18-21', 'gender': '0'}, {'level_0': '25', 'index': '25', 'time': '2467', 'age': '25-29', 'gender': '1'}, {'level_0': '26', 'index': '26', 'time': '7750', 'age': '45-49', 'gender': '0'}, {'level_0': '27', 'index': '27', 'time': '607', 'age': '22-24', 'gender': '0'}, {'level_0': '28', 'index': '28', 'time': '525', 'age': '22-24', 'gender': '1'}, {'level_0': '29', 'index': '29', 'time': '501', 'age': '18-21', 'gender': '0'}, {'level_0': '30', 'index': '30', 'time': '415', 'age': '22-24', 'gender': '0'}, {'level_0': '31', 'index': '31', 'time': '317', 'age': '30-34', 'gender': '0'}, {'level_0': '32', 'index': '32', 'time': '171', 'age': '22-24', 'gender': '2'}, {'level_0': '33', 'index': '33', 'time': '744', 'age': '30-34', 'gender': '1'}, {'level_0': '34', 'index': '34', 'time': '668', 'age': '22-24', 'gender': '0'}, {'level_0': '35', 'index': '35', 'time': '460', 'age': '30-34', 'gender': '1'}, {'level_0': '36', 'index': '36', 'time': '244', 'age': '25-29', 'gender': '1'}, {'level_0': '37', 'index': '37', 'time': '901', 'age': '30-34', 'gender': '0'}, {'level_0': '38', 'index': '38', 'time': '625', 'age': '22-24', 'gender': '0'}, {'level_0': '39', 'index': '39', 'time': '1239', 'age': '18-21', 'gender': '0'}, {'level_0': '40', 'index': '40', 'time': '229993', 'age': '25-29', 'gender': '0'}, {'level_0': '41', 'index': '41', 'time': '312', 'age': '25-29', 'gender': '0'}, {'level_0': '42', 'index': '42', 'time': '976', 'age': '55-59', 'gender': '0'}, {'level_0': '43', 'index': '43', 'time': '1890', 'age': '30-34', 'gender': '1'}, {'level_0': '44', 'index': '44', 'time': '357', 'age': '18-21', 'gender': '0'}, {'level_0': '45', 'index': '45', 'time': '660', 'age': '40-44', 'gender': '0'}, {'level_0': '46', 'index': '46', 'time': '1524', 'age': '22-24', 'gender': '0'}, {'level_0': '47', 'index': '47', 'time': '453', 'age': '18-21', 'gender': '1'}, {'level_0': '48', 'index': '48', 'time': '793', 'age': '25-29', 'gender': '0'}, {'level_0': '49', 'index': '49', 'time': '557', 'age': '30-34', 'gender': '1'}, {'level_0': '50', 'index': '50', 'time': '5215', 'age': '25-29', 'gender': '0'}, {'l ...

# %%
# Explicación tipos de datos xml_list:
# Vemos que es una lista de diccionarios, representando los registros de una tabla con varias columnas
# El diccionario se complone de: Keys (nombre de la columna) y Values (nombre del registro)
# En algunos diccionarios, vemos que estan con saltos de línea entre los ítems.

# %%
# Cambiar la key género de int a str

# %%
# SOLUCION QUE SE ME OCURRIO (ANA)

for i in range(len(xml_list)):  #entramos a cada elemento de la lista (o sea, cada diccionario)

    for k, v in xml_list[i].items(): #por cada key y value de cada diccionario:
        
        if k == "gender":       # si la key es = a gender (para que nos tome solo esa columna)
            
            if v == "0":                     # si el valor es "0":
              xml_list[i][k] = "Man"            # que vaya a la key de ese diccionario y cambie el value a "Man"
            
            elif v == "1":                      # lo mismo para el resto
                xml_list[i][k] = "Woman"
            elif v == "2":
                xml_list[i][k] = "Nonbinary"
            elif v == "3":
                xml_list[i][k] = "Prefer not to say"
            elif v == "4":
                xml_list[i][k] = "Prefer to self-describe"

# %%
# Cambiamos los nombres de las keys index_0 e index por index_xml e index_sql respectivamente 
for i in range(len(xml_list)):
    xml_list[i]['index_xml'] = xml_list[i].pop('level_0')
    xml_list[i]['index_sql'] = xml_list[i].pop('index')

# %%
xml_list
# Out:
# [{'time': '784',
#   'age': '50-54',
#   'gender': 'Man',
#   'index_xml': '1',
#   'index_sql': '1'},
#  {'time': '924',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '2',
#   'index_sql': '2'},
#  {'time': '575',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '3',
#   'index_sql': '3'},
#  {'time': '781',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '4',
#   'index_sql': '4'},
#  {'time': '1020',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '5',
#   'index_sql': '5'},
#  {'time': '141',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '6',
#   'index_sql': '6'},
#  {'time': '484',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '7',
#   'index_sql': '7'},
#  {'time': '1744',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '8',
#   'index_sql': '8'},
#  {'time': '655',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '9',
#   'index_sql': '9'},
#  {'time': '1777',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '10',
#   'index_sql': '10'},
#  {'time': '3081',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '11',
#   'index_sql': '11'},
#  {'time': '1922',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '12',
#   'index_sql': '12'},
#  {'time': '852',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '13',
#   'index_sql': '13'},
#  {'time': '838',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '14',
#   'index_sql': '14'},
#  {'time': '563',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '15',
#   'index_sql': '15'},
#  {'time': '1315',
#   'age': '50-54',
#   'gender': 'Man',
#   'index_xml': '16',
#   'index_sql': '16'},
#  {'time': '479',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '17',
#   'index_sql': '17'},
#  {'time': '249',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '18',
#   'index_sql': '18'},
#  {'time': '650',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '19',
#   'index_sql': '19'},
#  {'time': '1461',
#   'age': '70+',
#   'gender': 'Man',
#   'index_xml': '20',
#   'index_sql': '20'},
#  {'time': '551',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '21',
#   'index_sql': '21'},
#  {'time': '258',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '22',
#   'index_sql': '22'},
#  {'time': '773',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '23',
#   'index_sql': '23'},
#  {'time': '630',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '24',
#   'index_sql': '24'},
#  {'time': '2467',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '25',
#   'index_sql': '25'},
#  {'time': '7750',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '26',
#   'index_sql': '26'},
#  {'time': '607',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '27',
#   'index_sql': '27'},
#  {'time': '525',
#   'age': '22-24',
#   'gender': 'Woman',
#   'index_xml': '28',
#   'index_sql': '28'},
#  {'time': '501',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '29',
#   'index_sql': '29'},
#  {'time': '415',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '30',
#   'index_sql': '30'},
#  {'time': '317',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '31',
#   'index_sql': '31'},
#  {'time': '171',
#   'age': '22-24',
#   'gender': 'Nonbinary',
#   'index_xml': '32',
#   'index_sql': '32'},
#  {'time': '744',
#   'age': '30-34',
#   'gender': 'Woman',
#   'index_xml': '33',
#   'index_sql': '33'},
#  {'time': '668',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '34',
#   'index_sql': '34'},
#  {'time': '460',
#   'age': '30-34',
#   'gender': 'Woman',
#   'index_xml': '35',
#   'index_sql': '35'},
#  {'time': '244',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '36',
#   'index_sql': '36'},
#  {'time': '901',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '37',
#   'index_sql': '37'},
#  {'time': '625',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '38',
#   'index_sql': '38'},
#  {'time': '1239',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '39',
#   'index_sql': '39'},
#  {'time': '229993',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '40',
#   'index_sql': '40'},
#  {'time': '312',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '41',
#   'index_sql': '41'},
#  {'time': '976',
#   'age': '55-59',
#   'gender': 'Man',
#   'index_xml': '42',
#   'index_sql': '42'},
#  {'time': '1890',
#   'age': '30-34',
#   'gender': 'Woman',
#   'index_xml': '43',
#   'index_sql': '43'},
#  {'time': '357',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '44',
#   'index_sql': '44'},
#  {'time': '660',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '45',
#   'index_sql': '45'},
#  {'time': '1524',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '46',
#   'index_sql': '46'},
#  {'time': '453',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '47',
#   'index_sql': '47'},
#  {'time': '793',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '48',
#   'index_sql': '48'},
#  {'time': '557',
#   'age': '30-34',
#   'gender': 'Woman',
#   'index_xml': '49',
#   'index_sql': '49'},
#  {'time': '5215',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '50',
#   'index_sql': '50'},
#  {'time': '483',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '51',
#   'index_sql': '51'},
#  {'time': '866',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '52',
#   'index_sql': '52'},
#  {'time': '1045',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '53',
#   'index_sql': '53'},
#  {'time': '359',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '54',
#   'index_sql': '54'},
#  {'time': '1006',
#   'age': '22-24',
#   'gender': 'Woman',
#   'index_xml': '55',
#   'index_sql': '55'},
#  {'time': '95756',
#   'age': '30-34',
#   'gender': 'Woman',
#   'index_xml': '56',
#   'index_sql': '56'},
#  {'time': '642',
#   'age': '35-39',
#   'gender': 'Woman',
#   'index_xml': '57',
#   'index_sql': '57'},
#  {'time': '528',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '58',
#   'index_sql': '58'},
#  {'time': '1093',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '59',
#   'index_sql': '59'},
#  {'time': '565',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '60',
#   'index_sql': '60'},
#  {'time': '405',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '61',
#   'index_sql': '61'},
#  {'time': '872',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '62',
#   'index_sql': '62'},
#  {'time': '434',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '63',
#   'index_sql': '63'},
#  {'time': '419',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '64',
#   'index_sql': '64'},
#  {'time': '1479',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '65',
#   'index_sql': '65'},
#  {'time': '665',
#   'age': '30-34',
#   'gender': 'Prefer not to say',
#   'index_xml': '66',
#   'index_sql': '66'},
#  {'time': '1073',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '67',
#   'index_sql': '67'},
#  {'time': '626',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '68',
#   'index_sql': '68'},
#  {'time': '743',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '69',
#   'index_sql': '69'},
#  {'time': '854',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '70',
#   'index_sql': '70'},
#  {'time': '767',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '71',
#   'index_sql': '71'},
#  {'time': '4971',
#   'age': '30-34',
#   'gender': 'Woman',
#   'index_xml': '72',
#   'index_sql': '72'},
#  {'time': '560',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '73',
#   'index_sql': '73'},
#  {'time': '2399',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '74',
#   'index_sql': '74'},
#  {'time': '786',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '75',
#   'index_sql': '75'},
#  {'time': '1293',
#   'age': '50-54',
#   'gender': 'Man',
#   'index_xml': '76',
#   'index_sql': '76'},
#  {'time': '395',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '77',
#   'index_sql': '77'},
#  {'time': '555',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '78',
#   'index_sql': '78'},
#  {'time': '77678',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '79',
#   'index_sql': '79'},
#  {'time': '1643',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '80',
#   'index_sql': '80'},
#  {'time': '3454',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '81',
#   'index_sql': '81'},
#  {'time': '986',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '82',
#   'index_sql': '82'},
#  {'time': '1062',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '83',
#   'index_sql': '83'},
#  {'time': '161',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '84',
#   'index_sql': '84'},
#  {'time': '648',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '85',
#   'index_sql': '85'},
#  {'time': '432',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '86',
#   'index_sql': '86'},
#  {'time': '508',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '87',
#   'index_sql': '87'},
#  {'time': '463',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '88',
#   'index_sql': '88'},
#  {'time': '642',
#   'age': '55-59',
#   'gender': 'Man',
#   'index_xml': '89',
#   'index_sql': '89'},
#  {'time': '50748',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '90',
#   'index_sql': '90'},
#  {'time': '674',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '91',
#   'index_sql': '91'},
#  {'time': '548',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '92',
#   'index_sql': '92'},
#  {'time': '750',
#   'age': '55-59',
#   'gender': 'Man',
#   'index_xml': '93',
#   'index_sql': '93'},
#  {'time': '532',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '94',
#   'index_sql': '94'},
#  {'time': '1423',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '95',
#   'index_sql': '95'},
#  {'time': '661',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '96',
#   'index_sql': '96'},
#  {'time': '638',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '97',
#   'index_sql': '97'},
#  {'time': '585',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '98',
#   'index_sql': '98'},
#  {'time': '370',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '99',
#   'index_sql': '99'},
#  {'time': '174',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '100',
#   'index_sql': '100'},
#  {'time': '294',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '101',
#   'index_sql': '101'},
#  {'time': '681',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '102',
#   'index_sql': '102'},
#  {'time': '444',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '103',
#   'index_sql': '103'},
#  {'time': '543',
#   'age': '40-44',
#   'gender': 'Woman',
#   'index_xml': '104',
#   'index_sql': '104'},
#  {'time': '824',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '105',
#   'index_sql': '105'},
#  {'time': '3455',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '106',
#   'index_sql': '106'},
#  {'time': '728',
#   'age': '55-59',
#   'gender': 'Man',
#   'index_xml': '107',
#   'index_sql': '107'},
#  {'time': '3097',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '108',
#   'index_sql': '108'},
#  {'time': '531',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '109',
#   'index_sql': '109'},
#  {'time': '699',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '110',
#   'index_sql': '110'},
#  {'time': '378',
#   'age': '22-24',
#   'gender': 'Woman',
#   'index_xml': '111',
#   'index_sql': '111'},
#  {'time': '2932',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '112',
#   'index_sql': '112'},
#  {'time': '584',
#   'age': '30-34',
#   'gender': 'Woman',
#   'index_xml': '113',
#   'index_sql': '113'},
#  {'time': '205',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '114',
#   'index_sql': '114'},
#  {'time': '1050',
#   'age': '60-69',
#   'gender': 'Man',
#   'index_xml': '115',
#   'index_sql': '115'},
#  {'time': '61432',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '116',
#   'index_sql': '116'},
#  {'time': '445',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '117',
#   'index_sql': '117'},
#  {'time': '918',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '118',
#   'index_sql': '118'},
#  {'time': '798',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '119',
#   'index_sql': '119'},
#  {'time': '131',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '120',
#   'index_sql': '120'},
#  {'time': '735',
#   'age': '70+',
#   'gender': 'Man',
#   'index_xml': '121',
#   'index_sql': '121'},
#  {'time': '654',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '122',
#   'index_sql': '122'},
#  {'time': '2770',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '123',
#   'index_sql': '123'},
#  {'time': '1533',
#   'age': '60-69',
#   'gender': 'Man',
#   'index_xml': '124',
#   'index_sql': '124'},
#  {'time': '2885',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '125',
#   'index_sql': '125'},
#  {'time': '1730',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '126',
#   'index_sql': '126'},
#  {'time': '379',
#   'age': '40-44',
#   'gender': 'Woman',
#   'index_xml': '127',
#   'index_sql': '127'},
#  {'time': '763',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '128',
#   'index_sql': '128'},
#  {'time': '694',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '129',
#   'index_sql': '129'},
#  {'time': '776',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '130',
#   'index_sql': '130'},
#  {'time': '737',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '131',
#   'index_sql': '131'},
#  {'time': '514',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '132',
#   'index_sql': '132'},
#  {'time': '647',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '133',
#   'index_sql': '133'},
#  {'time': '386',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '134',
#   'index_sql': '134'},
#  {'time': '2048',
#   'age': '30-34',
#   'gender': 'Woman',
#   'index_xml': '135',
#   'index_sql': '135'},
#  {'time': '43508',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '136',
#   'index_sql': '136'},
#  {'time': '401',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '137',
#   'index_sql': '137'},
#  {'time': '682',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '138',
#   'index_sql': '138'},
#  {'time': '753',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '139',
#   'index_sql': '139'},
#  {'time': '352',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '140',
#   'index_sql': '140'},
#  {'time': '566',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '141',
#   'index_sql': '141'},
#  {'time': '1813',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '142',
#   'index_sql': '142'},
#  {'time': '435',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '143',
#   'index_sql': '143'},
#  {'time': '986',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '144',
#   'index_sql': '144'},
#  {'time': '366',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '145',
#   'index_sql': '145'},
#  {'time': '776',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '146',
#   'index_sql': '146'},
#  {'time': '340',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '147',
#   'index_sql': '147'},
#  {'time': '339',
#   'age': '30-34',
#   'gender': 'Woman',
#   'index_xml': '148',
#   'index_sql': '148'},
#  {'time': '436',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '149',
#   'index_sql': '149'},
#  {'time': '744',
#   'age': '70+',
#   'gender': 'Woman',
#   'index_xml': '150',
#   'index_sql': '150'},
#  {'time': '895',
#   'age': '22-24',
#   'gender': 'Woman',
#   'index_xml': '151',
#   'index_sql': '151'},
#  {'time': '79172',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '152',
#   'index_sql': '152'},
#  {'time': '502',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '153',
#   'index_sql': '153'},
#  {'time': '267',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '154',
#   'index_sql': '154'},
#  {'time': '516',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '155',
#   'index_sql': '155'},
#  {'time': '427',
#   'age': '22-24',
#   'gender': 'Woman',
#   'index_xml': '156',
#   'index_sql': '156'},
#  {'time': '985',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '157',
#   'index_sql': '157'},
#  {'time': '610',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '158',
#   'index_sql': '158'},
#  {'time': '304',
#   'age': '22-24',
#   'gender': 'Woman',
#   'index_xml': '159',
#   'index_sql': '159'},
#  {'time': '12878',
#   'age': '50-54',
#   'gender': 'Man',
#   'index_xml': '160',
#   'index_sql': '160'},
#  {'time': '526',
#   'age': '60-69',
#   'gender': 'Man',
#   'index_xml': '161',
#   'index_sql': '161'},
#  {'time': '1068',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '162',
#   'index_sql': '162'},
#  {'time': '404',
#   'age': '22-24',
#   'gender': 'Woman',
#   'index_xml': '163',
#   'index_sql': '163'},
#  {'time': '280',
#   'age': '50-54',
#   'gender': 'Man',
#   'index_xml': '164',
#   'index_sql': '164'},
#  {'time': '904',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '165',
#   'index_sql': '165'},
#  {'time': '1565',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '166',
#   'index_sql': '166'},
#  {'time': '3089',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '167',
#   'index_sql': '167'},
#  {'time': '447',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '168',
#   'index_sql': '168'},
#  {'time': '460',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '169',
#   'index_sql': '169'},
#  {'time': '1846',
#   'age': '60-69',
#   'gender': 'Man',
#   'index_xml': '170',
#   'index_sql': '170'},
#  {'time': '980',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '171',
#   'index_sql': '171'},
#  {'time': '660',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '172',
#   'index_sql': '172'},
#  {'time': '937',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '173',
#   'index_sql': '173'},
#  {'time': '476',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '174',
#   'index_sql': '174'},
#  {'time': '553',
#   'age': '40-44',
#   'gender': 'Woman',
#   'index_xml': '175',
#   'index_sql': '175'},
#  {'time': '412',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '176',
#   'index_sql': '176'},
#  {'time': '324',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '177',
#   'index_sql': '177'},
#  {'time': '1894',
#   'age': '22-24',
#   'gender': 'Woman',
#   'index_xml': '178',
#   'index_sql': '178'},
#  {'time': '1762',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '179',
#   'index_sql': '179'},
#  {'time': '866',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '180',
#   'index_sql': '180'},
#  {'time': '24380',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '181',
#   'index_sql': '181'},
#  {'time': '738',
#   'age': '22-24',
#   'gender': 'Woman',
#   'index_xml': '182',
#   'index_sql': '182'},
#  {'time': '2032',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '183',
#   'index_sql': '183'},
#  {'time': '2084',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '184',
#   'index_sql': '184'},
#  {'time': '698',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '185',
#   'index_sql': '185'},
#  {'time': '574',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '186',
#   'index_sql': '186'},
#  {'time': '778',
#   'age': '60-69',
#   'gender': 'Man',
#   'index_xml': '187',
#   'index_sql': '187'},
#  {'time': '493',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '188',
#   'index_sql': '188'},
#  {'time': '337',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '189',
#   'index_sql': '189'},
#  {'time': '406',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '190',
#   'index_sql': '190'},
#  {'time': '1677',
#   'age': '55-59',
#   'gender': 'Man',
#   'index_xml': '191',
#   'index_sql': '191'},
#  {'time': '348',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '192',
#   'index_sql': '192'},
#  {'time': '536',
#   'age': '30-34',
#   'gender': 'Woman',
#   'index_xml': '193',
#   'index_sql': '193'},
#  {'time': '186',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '194',
#   'index_sql': '194'},
#  {'time': '354',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '195',
#   'index_sql': '195'},
#  {'time': '375',
#   'age': '22-24',
#   'gender': 'Woman',
#   'index_xml': '196',
#   'index_sql': '196'},
#  {'time': '677',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '197',
#   'index_sql': '197'},
#  {'time': '456',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '198',
#   'index_sql': '198'},
#  {'time': '916',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '199',
#   'index_sql': '199'},
#  {'time': '571',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '200',
#   'index_sql': '200'},
#  {'time': '720',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '201',
#   'index_sql': '201'},
#  {'time': '539',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '202',
#   'index_sql': '202'},
#  {'time': '1346',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '203',
#   'index_sql': '203'},
#  {'time': '338',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '204',
#   'index_sql': '204'},
#  {'time': '307',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '205',
#   'index_sql': '205'},
#  {'time': '288',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '206',
#   'index_sql': '206'},
#  {'time': '501',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '207',
#   'index_sql': '207'},
#  {'time': '2331',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '208',
#   'index_sql': '208'},
#  {'time': '3237',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '209',
#   'index_sql': '209'},
#  {'time': '531',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '210',
#   'index_sql': '210'},
#  {'time': '586',
#   'age': '30-34',
#   'gender': 'Nonbinary',
#   'index_xml': '211',
#   'index_sql': '211'},
#  {'time': '12370',
#   'age': '55-59',
#   'gender': 'Man',
#   'index_xml': '212',
#   'index_sql': '212'},
#  {'time': '1233',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '213',
#   'index_sql': '213'},
#  {'time': '697',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '214',
#   'index_sql': '214'},
#  {'time': '578',
#   'age': '35-39',
#   'gender': 'Woman',
#   'index_xml': '215',
#   'index_sql': '215'},
#  {'time': '572',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '216',
#   'index_sql': '216'},
#  {'time': '224',
#   'age': '18-21',
#   'gender': 'Prefer not to say',
#   'index_xml': '217',
#   'index_sql': '217'},
#  {'time': '646',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '218',
#   'index_sql': '218'},
#  {'time': '794',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '219',
#   'index_sql': '219'},
#  {'time': '815',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '220',
#   'index_sql': '220'},
#  {'time': '591',
#   'age': '60-69',
#   'gender': 'Man',
#   'index_xml': '221',
#   'index_sql': '221'},
#  {'time': '699',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '222',
#   'index_sql': '222'},
#  {'time': '1124',
#   'age': '70+',
#   'gender': 'Man',
#   'index_xml': '223',
#   'index_sql': '223'},
#  {'time': '520',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '224',
#   'index_sql': '224'},
#  {'time': '504',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '225',
#   'index_sql': '225'},
#  {'time': '669',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '226',
#   'index_sql': '226'},
#  {'time': '3042',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '227',
#   'index_sql': '227'},
#  {'time': '982',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '228',
#   'index_sql': '228'},
#  {'time': '613',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '229',
#   'index_sql': '229'},
#  {'time': '798',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '230',
#   'index_sql': '230'},
#  {'time': '875',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '231',
#   'index_sql': '231'},
#  {'time': '307',
#   'age': '55-59',
#   'gender': 'Woman',
#   'index_xml': '232',
#   'index_sql': '232'},
#  {'time': '4131',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '233',
#   'index_sql': '233'},
#  {'time': '601',
#   'age': '50-54',
#   'gender': 'Man',
#   'index_xml': '234',
#   'index_sql': '234'},
#  {'time': '1341',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '235',
#   'index_sql': '235'},
#  {'time': '612',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '236',
#   'index_sql': '236'},
#  {'time': '275',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '237',
#   'index_sql': '237'},
#  {'time': '1128',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '238',
#   'index_sql': '238'},
#  {'time': '961',
#   'age': '50-54',
#   'gender': 'Man',
#   'index_xml': '239',
#   'index_sql': '239'},
#  {'time': '290',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '240',
#   'index_sql': '240'},
#  {'time': '627',
#   'age': '30-34',
#   'gender': 'Woman',
#   'index_xml': '241',
#   'index_sql': '241'},
#  {'time': '1348',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '242',
#   'index_sql': '242'},
#  {'time': '780',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '243',
#   'index_sql': '243'},
#  {'time': '9291',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '244',
#   'index_sql': '244'},
#  {'time': '3874',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '245',
#   'index_sql': '245'},
#  {'time': '1921',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '246',
#   'index_sql': '246'},
#  {'time': '497',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '247',
#   'index_sql': '247'},
#  {'time': '1181',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '248',
#   'index_sql': '248'},
#  {'time': '688',
#   'age': '35-39',
#   'gender': 'Woman',
#   'index_xml': '249',
#   'index_sql': '249'},
#  {'time': '449',
#   'age': '30-34',
#   'gender': 'Woman',
#   'index_xml': '250',
#   'index_sql': '250'},
#  {'time': '320',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '251',
#   'index_sql': '251'},
#  {'time': '767',
#   'age': '35-39',
#   'gender': 'Woman',
#   'index_xml': '252',
#   'index_sql': '252'},
#  {'time': '667',
#   'age': '55-59',
#   'gender': 'Woman',
#   'index_xml': '253',
#   'index_sql': '253'},
#  {'time': '170',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '254',
#   'index_sql': '254'},
#  {'time': '991',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '255',
#   'index_sql': '255'},
#  {'time': '1846',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '256',
#   'index_sql': '256'},
#  {'time': '732',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '257',
#   'index_sql': '257'},
#  {'time': '566',
#   'age': '60-69',
#   'gender': 'Man',
#   'index_xml': '258',
#   'index_sql': '258'},
#  {'time': '1075',
#   'age': '50-54',
#   'gender': 'Man',
#   'index_xml': '259',
#   'index_sql': '259'},
#  {'time': '442',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '260',
#   'index_sql': '260'},
#  {'time': '1469',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '261',
#   'index_sql': '261'},
#  {'time': '526',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '262',
#   'index_sql': '262'},
#  {'time': '824',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '263',
#   'index_sql': '263'},
#  {'time': '922',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '264',
#   'index_sql': '264'},
#  {'time': '378',
#   'age': '35-39',
#   'gender': 'Woman',
#   'index_xml': '265',
#   'index_sql': '265'},
#  {'time': '1945',
#   'age': '45-49',
#   'gender': 'Prefer not to say',
#   'index_xml': '266',
#   'index_sql': '266'},
#  {'time': '578',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '267',
#   'index_sql': '267'},
#  {'time': '237',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '268',
#   'index_sql': '268'},
#  {'time': '756',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '269',
#   'index_sql': '269'},
#  {'time': '599',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '270',
#   'index_sql': '270'},
#  {'time': '480',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '271',
#   'index_sql': '271'},
#  {'time': '264',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '272',
#   'index_sql': '272'},
#  {'time': '4088',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '273',
#   'index_sql': '273'},
#  {'time': '1066',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '274',
#   'index_sql': '274'},
#  {'time': '509',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '275',
#   'index_sql': '275'},
#  {'time': '187',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '276',
#   'index_sql': '276'},
#  {'time': '372',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '277',
#   'index_sql': '277'},
#  {'time': '356',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '278',
#   'index_sql': '278'},
#  {'time': '445',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '279',
#   'index_sql': '279'},
#  {'time': '841',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '280',
#   'index_sql': '280'},
#  {'time': '569',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '281',
#   'index_sql': '281'},
#  {'time': '984',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '282',
#   'index_sql': '282'},
#  {'time': '85290',
#   'age': '50-54',
#   'gender': 'Man',
#   'index_xml': '283',
#   'index_sql': '283'},
#  {'time': '3143',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '284',
#   'index_sql': '284'},
#  {'time': '1159',
#   'age': '45-49',
#   'gender': 'Woman',
#   'index_xml': '285',
#   'index_sql': '285'},
#  {'time': '5097',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '286',
#   'index_sql': '286'},
#  {'time': '501',
#   'age': '35-39',
#   'gender': 'Woman',
#   'index_xml': '287',
#   'index_sql': '287'},
#  {'time': '622',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '288',
#   'index_sql': '288'},
#  {'time': '785',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '289',
#   'index_sql': '289'},
#  {'time': '489',
#   'age': '22-24',
#   'gender': 'Woman',
#   'index_xml': '290',
#   'index_sql': '290'},
#  {'time': '1984',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '291',
#   'index_sql': '291'},
#  {'time': '1112',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '292',
#   'index_sql': '292'},
#  {'time': '904',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '293',
#   'index_sql': '293'},
#  {'time': '2403',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '294',
#   'index_sql': '294'},
#  {'time': '29434',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '295',
#   'index_sql': '295'},
#  {'time': '489',
#   'age': '30-34',
#   'gender': 'Woman',
#   'index_xml': '296',
#   'index_sql': '296'},
#  {'time': '843',
#   'age': '50-54',
#   'gender': 'Man',
#   'index_xml': '297',
#   'index_sql': '297'},
#  {'time': '42500',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '298',
#   'index_sql': '298'},
#  {'time': '266',
#   'age': '50-54',
#   'gender': 'Man',
#   'index_xml': '299',
#   'index_sql': '299'},
#  {'time': '1390',
#   'age': '30-34',
#   'gender': 'Woman',
#   'index_xml': '300',
#   'index_sql': '300'},
#  {'time': '887',
#   'age': '25-29',
#   'gender': 'Prefer not to say',
#   'index_xml': '301',
#   'index_sql': '301'},
#  {'time': '662',
#   'age': '22-24',
#   'gender': 'Woman',
#   'index_xml': '302',
#   'index_sql': '302'},
#  {'time': '559',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '303',
#   'index_sql': '303'},
#  {'time': '774',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '304',
#   'index_sql': '304'},
#  {'time': '603',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '305',
#   'index_sql': '305'},
#  {'time': '550',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '306',
#   'index_sql': '306'},
#  {'time': '3074',
#   'age': '30-34',
#   'gender': 'Nonbinary',
#   'index_xml': '307',
#   'index_sql': '307'},
#  {'time': '161',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '308',
#   'index_sql': '308'},
#  {'time': '828',
#   'age': '35-39',
#   'gender': 'Woman',
#   'index_xml': '309',
#   'index_sql': '309'},
#  {'time': '994',
#   'age': '60-69',
#   'gender': 'Man',
#   'index_xml': '310',
#   'index_sql': '310'},
#  {'time': '545',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '311',
#   'index_sql': '311'},
#  {'time': '544',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '312',
#   'index_sql': '312'},
#  {'time': '358',
#   'age': '60-69',
#   'gender': 'Man',
#   'index_xml': '313',
#   'index_sql': '313'},
#  {'time': '364',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '314',
#   'index_sql': '314'},
#  {'time': '771',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '315',
#   'index_sql': '315'},
#  {'time': '345',
#   'age': '35-39',
#   'gender': 'Woman',
#   'index_xml': '316',
#   'index_sql': '316'},
#  {'time': '231',
#   'age': '22-24',
#   'gender': 'Woman',
#   'index_xml': '317',
#   'index_sql': '317'},
#  {'time': '255',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '318',
#   'index_sql': '318'},
#  {'time': '6005',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '319',
#   'index_sql': '319'},
#  {'time': '245',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '320',
#   'index_sql': '320'},
#  {'time': '166328',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '321',
#   'index_sql': '321'},
#  {'time': '1072',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '322',
#   'index_sql': '322'},
#  {'time': '1272',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '323',
#   'index_sql': '323'},
#  {'time': '434',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '324',
#   'index_sql': '324'},
#  {'time': '4573',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '325',
#   'index_sql': '325'},
#  {'time': '584',
#   'age': '30-34',
#   'gender': 'Woman',
#   'index_xml': '326',
#   'index_sql': '326'},
#  {'time': '979',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '327',
#   'index_sql': '327'},
#  {'time': '166',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '328',
#   'index_sql': '328'},
#  {'time': '673',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '329',
#   'index_sql': '329'},
#  {'time': '230',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '330',
#   'index_sql': '330'},
#  {'time': '39789',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '331',
#   'index_sql': '331'},
#  {'time': '3588',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '332',
#   'index_sql': '332'},
#  {'time': '784',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '333',
#   'index_sql': '333'},
#  {'time': '642',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '334',
#   'index_sql': '334'},
#  {'time': '1028',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '335',
#   'index_sql': '335'},
#  {'time': '1508',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '336',
#   'index_sql': '336'},
#  {'time': '151',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '337',
#   'index_sql': '337'},
#  {'time': '867',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '338',
#   'index_sql': '338'},
#  {'time': '451',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '339',
#   'index_sql': '339'},
#  {'time': '429',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '340',
#   'index_sql': '340'},
#  {'time': '1135',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '341',
#   'index_sql': '341'},
#  {'time': '799',
#   'age': '70+',
#   'gender': 'Man',
#   'index_xml': '342',
#   'index_sql': '342'},
#  {'time': '454',
#   'age': '50-54',
#   'gender': 'Man',
#   'index_xml': '343',
#   'index_sql': '343'},
#  {'time': '424',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '344',
#   'index_sql': '344'},
#  {'time': '1089',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '345',
#   'index_sql': '345'},
#  {'time': '749',
#   'age': '55-59',
#   'gender': 'Man',
#   'index_xml': '346',
#   'index_sql': '346'},
#  {'time': '496',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '347',
#   'index_sql': '347'},
#  {'time': '505',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '348',
#   'index_sql': '348'},
#  {'time': '5394',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '349',
#   'index_sql': '349'},
#  {'time': '319',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '350',
#   'index_sql': '350'},
#  {'time': '639',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '351',
#   'index_sql': '351'},
#  {'time': '405',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '352',
#   'index_sql': '352'},
#  {'time': '808',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '353',
#   'index_sql': '353'},
#  {'time': '1011',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '354',
#   'index_sql': '354'},
#  {'time': '780',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '355',
#   'index_sql': '355'},
#  {'time': '642',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '356',
#   'index_sql': '356'},
#  {'time': '623',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '357',
#   'index_sql': '357'},
#  {'time': '450',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '358',
#   'index_sql': '358'},
#  {'time': '951',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '359',
#   'index_sql': '359'},
#  {'time': '244',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '360',
#   'index_sql': '360'},
#  {'time': '365',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '361',
#   'index_sql': '361'},
#  {'time': '589',
#   'age': '55-59',
#   'gender': 'Man',
#   'index_xml': '362',
#   'index_sql': '362'},
#  {'time': '502',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '363',
#   'index_sql': '363'},
#  {'time': '1276',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '364',
#   'index_sql': '364'},
#  {'time': '2017',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '365',
#   'index_sql': '365'},
#  {'time': '700561',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '366',
#   'index_sql': '366'},
#  {'time': '415',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '367',
#   'index_sql': '367'},
#  {'time': '2355',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '368',
#   'index_sql': '368'},
#  {'time': '699',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '369',
#   'index_sql': '369'},
#  {'time': '1724',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '370',
#   'index_sql': '370'},
#  {'time': '454',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '371',
#   'index_sql': '371'},
#  {'time': '997',
#   'age': '50-54',
#   'gender': 'Man',
#   'index_xml': '372',
#   'index_sql': '372'},
#  {'time': '3411',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '373',
#   'index_sql': '373'},
#  {'time': '569',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '374',
#   'index_sql': '374'},
#  {'time': '1254',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '375',
#   'index_sql': '375'},
#  {'time': '1507',
#   'age': '60-69',
#   'gender': 'Man',
#   'index_xml': '376',
#   'index_sql': '376'},
#  {'time': '569',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '377',
#   'index_sql': '377'},
#  {'time': '1020',
#   'age': '60-69',
#   'gender': 'Man',
#   'index_xml': '378',
#   'index_sql': '378'},
#  {'time': '945',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '379',
#   'index_sql': '379'},
#  {'time': '1028',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '380',
#   'index_sql': '380'},
#  {'time': '585',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '381',
#   'index_sql': '381'},
#  {'time': '1489',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '382',
#   'index_sql': '382'},
#  {'time': '392',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '383',
#   'index_sql': '383'},
#  {'time': '3301',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '384',
#   'index_sql': '384'},
#  {'time': '257',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '385',
#   'index_sql': '385'},
#  {'time': '973',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '386',
#   'index_sql': '386'},
#  {'time': '458',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '387',
#   'index_sql': '387'},
#  {'time': '353',
#   'age': '18-21',
#   'gender': 'Prefer not to say',
#   'index_xml': '388',
#   'index_sql': '388'},
#  {'time': '987',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '389',
#   'index_sql': '389'},
#  {'time': '1208',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '390',
#   'index_sql': '390'},
#  {'time': '482',
#   'age': '50-54',
#   'gender': 'Man',
#   'index_xml': '391',
#   'index_sql': '391'},
#  {'time': '788',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '392',
#   'index_sql': '392'},
#  {'time': '521',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '393',
#   'index_sql': '393'},
#  {'time': '1114',
#   'age': '50-54',
#   'gender': 'Woman',
#   'index_xml': '394',
#   'index_sql': '394'},
#  {'time': '1133',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '395',
#   'index_sql': '395'},
#  {'time': '856',
#   'age': '50-54',
#   'gender': 'Man',
#   'index_xml': '396',
#   'index_sql': '396'},
#  {'time': '974',
#   'age': '50-54',
#   'gender': 'Man',
#   'index_xml': '397',
#   'index_sql': '397'},
#  {'time': '358',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '398',
#   'index_sql': '398'},
#  {'time': '602',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '399',
#   'index_sql': '399'},
#  {'time': '610',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '400',
#   'index_sql': '400'},
#  {'time': '1755',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '401',
#   'index_sql': '401'},
#  {'time': '733',
#   'age': '22-24',
#   'gender': 'Woman',
#   'index_xml': '402',
#   'index_sql': '402'},
#  {'time': '984',
#   'age': '35-39',
#   'gender': 'Woman',
#   'index_xml': '403',
#   'index_sql': '403'},
#  {'time': '1155',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '404',
#   'index_sql': '404'},
#  {'time': '4082',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '405',
#   'index_sql': '405'},
#  {'time': '918',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '406',
#   'index_sql': '406'},
#  {'time': '779',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '407',
#   'index_sql': '407'},
#  {'time': '394',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '408',
#   'index_sql': '408'},
#  {'time': '670',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '409',
#   'index_sql': '409'},
#  {'time': '2239',
#   'age': '55-59',
#   'gender': 'Woman',
#   'index_xml': '410',
#   'index_sql': '410'},
#  {'time': '2377',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '411',
#   'index_sql': '411'},
#  {'time': '572',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '412',
#   'index_sql': '412'},
#  {'time': '913',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '413',
#   'index_sql': '413'},
#  {'time': '764',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '414',
#   'index_sql': '414'},
#  {'time': '601',
#   'age': '45-49',
#   'gender': 'Woman',
#   'index_xml': '415',
#   'index_sql': '415'},
#  {'time': '663',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '416',
#   'index_sql': '416'},
#  {'time': '659',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '417',
#   'index_sql': '417'},
#  {'time': '1497',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '418',
#   'index_sql': '418'},
#  {'time': '3356',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '419',
#   'index_sql': '419'},
#  {'time': '838',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '420',
#   'index_sql': '420'},
#  {'time': '270',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '421',
#   'index_sql': '421'},
#  {'time': '943',
#   'age': '40-44',
#   'gender': 'Prefer not to say',
#   'index_xml': '422',
#   'index_sql': '422'},
#  {'time': '1877',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '423',
#   'index_sql': '423'},
#  {'time': '914',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '424',
#   'index_sql': '424'},
#  {'time': '1441',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '425',
#   'index_sql': '425'},
#  {'time': '310',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '426',
#   'index_sql': '426'},
#  {'time': '1003',
#   'age': '35-39',
#   'gender': 'Woman',
#   'index_xml': '427',
#   'index_sql': '427'},
#  {'time': '481',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '428',
#   'index_sql': '428'},
#  {'time': '639',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '429',
#   'index_sql': '429'},
#  {'time': '616',
#   'age': '30-34',
#   'gender': 'Woman',
#   'index_xml': '430',
#   'index_sql': '430'},
#  {'time': '704',
#   'age': '30-34',
#   'gender': 'Woman',
#   'index_xml': '431',
#   'index_sql': '431'},
#  {'time': '899193',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '432',
#   'index_sql': '432'},
#  {'time': '899',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '433',
#   'index_sql': '433'},
#  {'time': '572',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '434',
#   'index_sql': '434'},
#  {'time': '330',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '435',
#   'index_sql': '435'},
#  {'time': '1080',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '436',
#   'index_sql': '436'},
#  {'time': '8327',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '437',
#   'index_sql': '437'},
#  {'time': '403',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '438',
#   'index_sql': '438'},
#  {'time': '448',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '439',
#   'index_sql': '439'},
#  {'time': '541',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '440',
#   'index_sql': '440'},
#  {'time': '883',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '441',
#   'index_sql': '441'},
#  {'time': '155',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '442',
#   'index_sql': '442'},
#  {'time': '995',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '443',
#   'index_sql': '443'},
#  {'time': '772',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '444',
#   'index_sql': '444'},
#  {'time': '448',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '445',
#   'index_sql': '445'},
#  {'time': '2046',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '446',
#   'index_sql': '446'},
#  {'time': '642',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '447',
#   'index_sql': '447'},
#  {'time': '703',
#   'age': '35-39',
#   'gender': 'Woman',
#   'index_xml': '448',
#   'index_sql': '448'},
#  {'time': '994',
#   'age': '22-24',
#   'gender': 'Prefer to self-describe',
#   'index_xml': '449',
#   'index_sql': '449'},
#  {'time': '316',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '450',
#   'index_sql': '450'},
#  {'time': '1004',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '451',
#   'index_sql': '451'},
#  {'time': '1556',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '452',
#   'index_sql': '452'},
#  {'time': '447',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '453',
#   'index_sql': '453'},
#  {'time': '387',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '454',
#   'index_sql': '454'},
#  {'time': '1230',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '455',
#   'index_sql': '455'},
#  {'time': '447',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '456',
#   'index_sql': '456'},
#  {'time': '644',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '457',
#   'index_sql': '457'},
#  {'time': '689',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '458',
#   'index_sql': '458'},
#  {'time': '628',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '459',
#   'index_sql': '459'},
#  {'time': '439',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '460',
#   'index_sql': '460'},
#  {'time': '605',
#   'age': '30-34',
#   'gender': 'Woman',
#   'index_xml': '461',
#   'index_sql': '461'},
#  {'time': '208',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '462',
#   'index_sql': '462'},
#  {'time': '820',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '463',
#   'index_sql': '463'},
#  {'time': '224',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '464',
#   'index_sql': '464'},
#  {'time': '319',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '465',
#   'index_sql': '465'},
#  {'time': '1549',
#   'age': '50-54',
#   'gender': 'Man',
#   'index_xml': '466',
#   'index_sql': '466'},
#  {'time': '658',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '467',
#   'index_sql': '467'},
#  {'time': '395',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '468',
#   'index_sql': '468'},
#  {'time': '1459',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '469',
#   'index_sql': '469'},
#  {'time': '1374',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '470',
#   'index_sql': '470'},
#  {'time': '11771',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '471',
#   'index_sql': '471'},
#  {'time': '774',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '472',
#   'index_sql': '472'},
#  {'time': '584',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '473',
#   'index_sql': '473'},
#  {'time': '22868',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '474',
#   'index_sql': '474'},
#  {'time': '323',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '475',
#   'index_sql': '475'},
#  {'time': '414',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '476',
#   'index_sql': '476'},
#  {'time': '1927',
#   'age': '22-24',
#   'gender': 'Woman',
#   'index_xml': '477',
#   'index_sql': '477'},
#  {'time': '293',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '478',
#   'index_sql': '478'},
#  {'time': '501',
#   'age': '22-24',
#   'gender': 'Woman',
#   'index_xml': '479',
#   'index_sql': '479'},
#  {'time': '248332',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '480',
#   'index_sql': '480'},
#  {'time': '948',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '481',
#   'index_sql': '481'},
#  {'time': '964611',
#   'age': '50-54',
#   'gender': 'Woman',
#   'index_xml': '482',
#   'index_sql': '482'},
# ...
#   'index_sql': '840'},
#  {'time': '811',
#   'age': '50-54',
#   'gender': 'Man',
#   'index_xml': '841',
#   'index_sql': '841'},
#  {'time': '716',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '842',
#   'index_sql': '842'},
#  {'time': '404',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '843',
#   'index_sql': '843'},
#  {'time': '225',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '844',
#   'index_sql': '844'},
#  {'time': '796',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '845',
#   'index_sql': '845'},
#  {'time': '984',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '846',
#   'index_sql': '846'},
#  {'time': '624',
#   'age': '60-69',
#   'gender': 'Man',
#   'index_xml': '847',
#   'index_sql': '847'},
#  {'time': '687',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '848',
#   'index_sql': '848'},
#  {'time': '1678',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '849',
#   'index_sql': '849'},
#  {'time': '481',
#   'age': '35-39',
#   'gender': 'Woman',
#   'index_xml': '850',
#   'index_sql': '850'},
#  {'time': '214',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '851',
#   'index_sql': '851'},
#  {'time': '418',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '852',
#   'index_sql': '852'},
#  {'time': '312',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '853',
#   'index_sql': '853'},
#  {'time': '608',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '854',
#   'index_sql': '854'},
#  {'time': '785',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '855',
#   'index_sql': '855'},
#  {'time': '1423',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '856',
#   'index_sql': '856'},
#  {'time': '504',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '857',
#   'index_sql': '857'},
#  {'time': '1450',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '858',
#   'index_sql': '858'},
#  {'time': '826',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '859',
#   'index_sql': '859'},
#  {'time': '902',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '860',
#   'index_sql': '860'},
#  {'time': '830',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '861',
#   'index_sql': '861'},
#  {'time': '1070',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '862',
#   'index_sql': '862'},
#  {'time': '308',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '863',
#   'index_sql': '863'},
#  {'time': '174416',
#   'age': '50-54',
#   'gender': 'Man',
#   'index_xml': '864',
#   'index_sql': '864'},
#  {'time': '381',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '865',
#   'index_sql': '865'},
#  {'time': '693',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '866',
#   'index_sql': '866'},
#  {'time': '691',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '867',
#   'index_sql': '867'},
#  {'time': '366',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '868',
#   'index_sql': '868'},
#  {'time': '1000',
#   'age': '55-59',
#   'gender': 'Man',
#   'index_xml': '869',
#   'index_sql': '869'},
#  {'time': '481',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '870',
#   'index_sql': '870'},
#  {'time': '520',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '871',
#   'index_sql': '871'},
#  {'time': '691',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '872',
#   'index_sql': '872'},
#  {'time': '752',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '873',
#   'index_sql': '873'},
#  {'time': '307',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '874',
#   'index_sql': '874'},
#  {'time': '506',
#   'age': '60-69',
#   'gender': 'Woman',
#   'index_xml': '875',
#   'index_sql': '875'},
#  {'time': '138',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '876',
#   'index_sql': '876'},
#  {'time': '590',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '877',
#   'index_sql': '877'},
#  {'time': '449',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '878',
#   'index_sql': '878'},
#  {'time': '1217',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '879',
#   'index_sql': '879'},
#  {'time': '714',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '880',
#   'index_sql': '880'},
#  {'time': '4584',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '881',
#   'index_sql': '881'},
#  {'time': '581',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '882',
#   'index_sql': '882'},
#  {'time': '360',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '883',
#   'index_sql': '883'},
#  {'time': '49733',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '884',
#   'index_sql': '884'},
#  {'time': '995',
#   'age': '30-34',
#   'gender': 'Woman',
#   'index_xml': '885',
#   'index_sql': '885'},
#  {'time': '32872',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '886',
#   'index_sql': '886'},
#  {'time': '344',
#   'age': '35-39',
#   'gender': 'Woman',
#   'index_xml': '887',
#   'index_sql': '887'},
#  {'time': '1144',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '888',
#   'index_sql': '888'},
#  {'time': '646',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '889',
#   'index_sql': '889'},
#  {'time': '213',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '890',
#   'index_sql': '890'},
#  {'time': '329',
#   'age': '40-44',
#   'gender': 'Woman',
#   'index_xml': '891',
#   'index_sql': '891'},
#  {'time': '433',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '892',
#   'index_sql': '892'},
#  {'time': '386',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '893',
#   'index_sql': '893'},
#  {'time': '1142',
#   'age': '50-54',
#   'gender': 'Man',
#   'index_xml': '894',
#   'index_sql': '894'},
#  {'time': '474',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '895',
#   'index_sql': '895'},
#  {'time': '1096',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '896',
#   'index_sql': '896'},
#  {'time': '494',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '897',
#   'index_sql': '897'},
#  {'time': '648',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '898',
#   'index_sql': '898'},
#  {'time': '1831',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '899',
#   'index_sql': '899'},
#  {'time': '1327',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '900',
#   'index_sql': '900'},
#  {'time': '366',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '901',
#   'index_sql': '901'},
#  {'time': '408',
#   'age': '60-69',
#   'gender': 'Man',
#   'index_xml': '902',
#   'index_sql': '902'},
#  {'time': '461',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '903',
#   'index_sql': '903'},
#  {'time': '692',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '904',
#   'index_sql': '904'},
#  {'time': '393',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '905',
#   'index_sql': '905'},
#  {'time': '332',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '906',
#   'index_sql': '906'},
#  {'time': '826',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '907',
#   'index_sql': '907'},
#  {'time': '426',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '908',
#   'index_sql': '908'},
#  {'time': '802',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '909',
#   'index_sql': '909'},
#  {'time': '3434',
#   'age': '40-44',
#   'gender': 'Woman',
#   'index_xml': '910',
#   'index_sql': '910'},
#  {'time': '388',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '911',
#   'index_sql': '911'},
#  {'time': '577',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '912',
#   'index_sql': '912'},
#  {'time': '483',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '913',
#   'index_sql': '913'},
#  {'time': '761',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '914',
#   'index_sql': '914'},
#  {'time': '3179',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '915',
#   'index_sql': '915'},
#  {'time': '7688',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '916',
#   'index_sql': '916'},
#  {'time': '775',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '917',
#   'index_sql': '917'},
#  {'time': '594',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '918',
#   'index_sql': '918'},
#  {'time': '862',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '919',
#   'index_sql': '919'},
#  {'time': '607',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '920',
#   'index_sql': '920'},
#  {'time': '557',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '921',
#   'index_sql': '921'},
#  {'time': '10121',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '922',
#   'index_sql': '922'},
#  {'time': '250',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '923',
#   'index_sql': '923'},
#  {'time': '945',
#   'age': '55-59',
#   'gender': 'Man',
#   'index_xml': '924',
#   'index_sql': '924'},
#  {'time': '639',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '925',
#   'index_sql': '925'},
#  {'time': '140',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '926',
#   'index_sql': '926'},
#  {'time': '690',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '927',
#   'index_sql': '927'},
#  {'time': '1255',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '928',
#   'index_sql': '928'},
#  {'time': '810',
#   'age': '70+',
#   'gender': 'Man',
#   'index_xml': '929',
#   'index_sql': '929'},
#  {'time': '789',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '930',
#   'index_sql': '930'},
#  {'time': '11688',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '931',
#   'index_sql': '931'},
#  {'time': '636',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '932',
#   'index_sql': '932'},
#  {'time': '1890',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '933',
#   'index_sql': '933'},
#  {'time': '1304',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '934',
#   'index_sql': '934'},
#  {'time': '878',
#   'age': '60-69',
#   'gender': 'Man',
#   'index_xml': '935',
#   'index_sql': '935'},
#  {'time': '360',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '936',
#   'index_sql': '936'},
#  {'time': '737',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '937',
#   'index_sql': '937'},
#  {'time': '19523',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '938',
#   'index_sql': '938'},
#  {'time': '253',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '939',
#   'index_sql': '939'},
#  {'time': '230',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '940',
#   'index_sql': '940'},
#  {'time': '371',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '941',
#   'index_sql': '941'},
#  {'time': '406',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '942',
#   'index_sql': '942'},
#  {'time': '1769',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '943',
#   'index_sql': '943'},
#  {'time': '2639',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '944',
#   'index_sql': '944'},
#  {'time': '163',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '945',
#   'index_sql': '945'},
#  {'time': '518',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '946',
#   'index_sql': '946'},
#  {'time': '168',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '947',
#   'index_sql': '947'},
#  {'time': '976',
#   'age': '55-59',
#   'gender': 'Man',
#   'index_xml': '948',
#   'index_sql': '948'},
#  {'time': '1047088',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '949',
#   'index_sql': '949'},
#  {'time': '1203',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '950',
#   'index_sql': '950'},
#  {'time': '725',
#   'age': '30-34',
#   'gender': 'Woman',
#   'index_xml': '951',
#   'index_sql': '951'},
#  {'time': '2978',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '952',
#   'index_sql': '952'},
#  {'time': '519',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '953',
#   'index_sql': '953'},
#  {'time': '1709',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '954',
#   'index_sql': '954'},
#  {'time': '544',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '955',
#   'index_sql': '955'},
#  {'time': '357',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '956',
#   'index_sql': '956'},
#  {'time': '477',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '957',
#   'index_sql': '957'},
#  {'time': '705',
#   'age': '35-39',
#   'gender': 'Woman',
#   'index_xml': '958',
#   'index_sql': '958'},
#  {'time': '627',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '959',
#   'index_sql': '959'},
#  {'time': '123158',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '960',
#   'index_sql': '960'},
#  {'time': '280',
#   'age': '50-54',
#   'gender': 'Woman',
#   'index_xml': '961',
#   'index_sql': '961'},
#  {'time': '472',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '962',
#   'index_sql': '962'},
#  {'time': '834',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '963',
#   'index_sql': '963'},
#  {'time': '542',
#   'age': '22-24',
#   'gender': 'Woman',
#   'index_xml': '964',
#   'index_sql': '964'},
#  {'time': '605',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '965',
#   'index_sql': '965'},
#  {'time': '1592',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '966',
#   'index_sql': '966'},
#  {'time': '548',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '967',
#   'index_sql': '967'},
#  {'time': '653',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '968',
#   'index_sql': '968'},
#  {'time': '715',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '969',
#   'index_sql': '969'},
#  {'time': '706',
#   'age': '35-39',
#   'gender': 'Man',
#   'index_xml': '970',
#   'index_sql': '970'},
#  {'time': '658',
#   'age': '30-34',
#   'gender': 'Woman',
#   'index_xml': '971',
#   'index_sql': '971'},
#  {'time': '296',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '972',
#   'index_sql': '972'},
#  {'time': '911',
#   'age': '40-44',
#   'gender': 'Woman',
#   'index_xml': '973',
#   'index_sql': '973'},
#  {'time': '680',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '974',
#   'index_sql': '974'},
#  {'time': '602',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '975',
#   'index_sql': '975'},
#  {'time': '684',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '976',
#   'index_sql': '976'},
#  {'time': '1112',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '977',
#   'index_sql': '977'},
#  {'time': '455',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '978',
#   'index_sql': '978'},
#  {'time': '497',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '979',
#   'index_sql': '979'},
#  {'time': '342',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '980',
#   'index_sql': '980'},
#  {'time': '2308',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '981',
#   'index_sql': '981'},
#  {'time': '677',
#   'age': '40-44',
#   'gender': 'Man',
#   'index_xml': '982',
#   'index_sql': '982'},
#  {'time': '935',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '983',
#   'index_sql': '983'},
#  {'time': '371',
#   'age': '22-24',
#   'gender': 'Woman',
#   'index_xml': '984',
#   'index_sql': '984'},
#  {'time': '524',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '985',
#   'index_sql': '985'},
#  {'time': '271',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '986',
#   'index_sql': '986'},
#  {'time': '861',
#   'age': '40-44',
#   'gender': 'Woman',
#   'index_xml': '987',
#   'index_sql': '987'},
#  {'time': '341',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '988',
#   'index_sql': '988'},
#  {'time': '575',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '989',
#   'index_sql': '989'},
#  {'time': '946',
#   'age': '45-49',
#   'gender': 'Man',
#   'index_xml': '990',
#   'index_sql': '990'},
#  {'time': '3800',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '991',
#   'index_sql': '991'},
#  {'time': '263',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '992',
#   'index_sql': '992'},
#  {'time': '539',
#   'age': '18-21',
#   'gender': 'Woman',
#   'index_xml': '993',
#   'index_sql': '993'},
#  {'time': '489',
#   'age': '30-34',
#   'gender': 'Man',
#   'index_xml': '994',
#   'index_sql': '994'},
#  {'time': '4121',
#   'age': '22-24',
#   'gender': 'Man',
#   'index_xml': '995',
#   'index_sql': '995'},
#  {'time': '226154',
#   'age': '25-29',
#   'gender': 'Man',
#   'index_xml': '996',
#   'index_sql': '996'},
#  {'time': '516',
#   'age': '35-39',
#   'gender': 'Woman',
#   'index_xml': '997',
#   'index_sql': '997'},
#  {'time': '1415',
#   'age': '18-21',
#   'gender': 'Man',
#   'index_xml': '998',
#   'index_sql': '998'},
#  {'time': '167',
#   'age': '25-29',
#   'gender': 'Woman',
#   'index_xml': '999',
#   'index_sql': '999'},
#  {'time': '309',
#   'age': '22-24',
#   'gender': 'Woman',
#   'index_xml': '1000',
#   'index_sql': '1000'},
#  ...]
